# %% [markdown]
# <br>
# <br>
#
# <p style='color:red;'><b>본 실습 중 다뤄지는 코드의 경우 Anaconda가 C drive가 아닌 다른 파티션에 설치된 분들은 일부 소스코드가 정상적으로 작동하지 않을 수 있습니다.</b></p>

# %% [markdown]
# <br>
# <br>
#
# ## 1. 텍스트 데이터 분석을 위한 라이브러리 설치 및 세팅

# %% [markdown]
# <br>
#
# ### 1-1) NLTK 설치

# %% [markdown]
# - Text Processing을 위한 라이브러리인 **nltk** library(Natural Language Toolkit)를 설치 및 세팅합니다.

# %%
# NLTK는 Anaconda 설치 시 이미 설치되어 있으므로 별도 설치가 불필요합니다.
# !pip install nltk==3.6.1

# Test processing을 위해 nltk package 를 import
import nltk
# Out:
# Collecting nltk==3.6.1
#   Downloading nltk-3.6.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 67.6 MB/s eta 0:00:00
# Requirement already satisfied: click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk==3.6.1) (8.1.3)
# Requirement already satisfied: regex in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk==3.6.1) (2022.9.13)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk==3.6.1) (4.64.1)
# Requirement already satisfied: joblib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from nltk==3.6.1) (1.2.0)
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Not uninstalling nltk at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'nltk'. No files were found to uninstall.
# Successfully installed nltk-3.6.1
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# 아래 명령어를 통해 download 대화상자를 열어 패키지를 다운로드 받아야 합니다.
# <br>인터넷 속도 저하 시 매우 오래 걸리므로, 패키지 설치 경로만 확인한 다음 \[ (nltk, downloaded) nltk_data.zip ] 의 파일들을 복사합니다.
# <br><br>경로 예시 : **"C:\Users\{컴퓨터 이름}\AppData\Roaming\nltk_data"**
# <br>
# **<p style='color:red;'>nltk_data 폴더 안에 corpora, taggers, tokenizers 폴더가 바로 위치하도록 복사해줘야 합니다.</p>**

# %%
# nltk.download()  # 텍스트 데이터 처리를 위한 패키지 다운로더

# Download following packages
# Corpora : stopwords, wordnet
# Models : averaged_perceptron_tagger, maxnet_treebank_pos_tagger, punkt

# %% [markdown]
# <br>
#
# ### 1-2) NLTK 테스트

# %%
# 전처리하고자 하는 문장을 String 변수로 저장한다
sentence = 'NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.'

# 각 문장을 토큰화한 결과를 출력한다
nltk.word_tokenize(sentence)[:10]  # 문장을 '단어 수준에서' 토큰화해 출력한다
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In [5], line 5
#       2 sentence = 'NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum.'
#       4 # 각 문장을 토큰화한 결과를 출력한다
# ----> 5 nltk.word_tokenize(sentence)[:10]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/tokenize/__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/tokenize/__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/local/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %% [markdown]
# <br>
#
# ### 1-3) Konlpy 설치

# %% [markdown]
# #### 1) Microsoft Build Tools 2015 를 설치합니다.
#
# - http://j.mp/30ToU8g 에서 **BuildTools_Full.exe** 파일을 다운로드 후 설치해주세요!
# <br><br>
#
# #### 2) Java SE Development Kit (JDK) 를 설치합니다.
#
# - 기존에 **Java 혹은 JDK가 설치되어 있을 시 삭제** 후 설치를 진행해주세요.
# - http://j.mp/30TopLq 에서 **jdk-8u221-windows-x64.exe** 파일을 다운로드 후 설치해주세요!
# <br>(설치 폴더 위치를 포함하여 기본 설정을 모두 그대로 유지한 채 설치해주셔야 합니다.)
# - Mac OS 사용자는 http://j.mp/2lBBj1h 에서 OS 버전에 맞는 설치 파일을 다운로드하여 설치합니다.
# <br><br>
#
# #### 3) 설치가 완료되면 아래 3개의 셀을 차례대로 실행하여 JPype1과 konlpy를 설치하고, tweepy를 다운그레이드해줍니다.

# %%
# JPype1 1.2.0 버전으로 설치를 진행합니다. (cp38 == Python 3.8.x version)
# Mac OS 사용자는 https://pypi.org/project/JPype1/1.2.0/#files 에서 OS 버전에 맞는 .whl 파일을 다운로드합니다. (이미 포함되어 있습니다.)
# !pip uninstall beautifulsoup
#!pip install beautifulsoup4==4.6.0
import bs4
# !pip install JPype1-1.4.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
bs4.__version__
# Out:
# WARNING: Skipping beautifulsoup as it is not installed.
# Processing ./JPype1-1.4.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from JPype1==1.4.1) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging->JPype1==1.4.1) (3.0.9)
# JPype1 is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# '4.11.1'

# %%
# "액세스가 거부되었습니다" 에러 발생 시,
# cmd(명령프롬프트) 우클릭 & 관리자권한으로 실행 후,
# "pip install konlpy==0.5.2"를 입력 및 실행하여 설치를 진행합니다.

# !pip install konlpy==0.5.2
# Out:
# Collecting konlpy==0.5.2
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 50.6 MB/s eta 0:00:00
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 11.3 MB/s eta 0:00:00
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml>=4.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from konlpy==0.5.2) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (465 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 KB 51.2 MB/s eta 0:00:00
# Collecting tweepy>=3.7.0
#   Downloading tweepy-4.13.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 KB 22.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from konlpy==0.5.2) (1.23.4)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from JPype1>=0.7.0->konlpy==0.5.2) (21.3)
# Requirement already satisfied: requests<3,>=2.27.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tweepy>=3.7.0->konlpy==0.5.2) (2.28.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tweepy>=3.7.0->konlpy==0.5.2) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tweepy>=3.7.0->konlpy==0.5.2) (3.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy>=3.7.0->konlpy==0.5.2) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy>=3.7.0->konlpy==0.5.2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy>=3.7.0->konlpy==0.5.2) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests<3,>=2.27.0->tweepy>=3.7.0->konlpy==0.5.2) (1.26.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging->JPype1>=0.7.0->konlpy==0.5.2) (3.0.9)
# Installing collected packages: beautifulsoup4, colorama, JPype1, tweepy, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.1
#     Not uninstalling beautifulsoup4 at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'beautifulsoup4'. No files were found to uninstall.
# Successfully installed JPype1-1.4.1 beautifulsoup4-4.6.0 colorama-0.4.6 konlpy-0.5.2 tweepy-4.13.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# "액세스가 거부되었습니다" 에러 발생 시,
# cmd(명령프롬프트) 우클릭 & 관리자권한으로 실행 후,
# "pip install tweepy==3.10.0"를 입력 및 실행하여 다운그레이드를 진행합니다. (참고 @ https://doitgrow.com/27)
# !pip3 uninstall tweepy
# !pip install tweepy==3.10.0
# Out:
# Found existing installation: tweepy 3.10.0
# Uninstalling tweepy-3.10.0:
#   Would remove:
#     /root/venv/lib/python3.9/site-packages/tweepy-3.10.0.dist-info/*
#     /root/venv/lib/python3.9/site-packages/tweepy/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Requirement already satisfied: tweepy==3.10.0 in /root/venv/lib/python3.9/site-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tweepy==3.10.0) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from tweepy==3.10.0) (1.16.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tweepy==3.10.0) (2.28.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->tweepy==3.10.0) (3.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (2022.9.24)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /root/venv/lib/python3.9/site-packages (from requests[socks]>=2.11.1->tweepy==3.10.0) (1.7.1)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
import tweepy

print(tweepy.__version__)
# Out:
# 4.13.0

# %% [markdown]
# <br>
# <br>
#
# ### 1-4) Konlpy 테스트
# <br>
#
# - <p style='color:red;'> <b>RuntimeError</b> 발생 시 <a href='https://bit.ly/3kIAhdE'>https://bit.ly/3kIAhdE</a> 의 내용을 따라 Java 환경변수를 설정한 다음, <b>Jupyter notebook을 완전히 재시작 후 실행</b>해주세요.</p>
# - **JVM** 관련 에러 발생 시 위에서 설치한 Java SE Development Kit (JDK)를 삭제한 다음 재설치하고 재부팅해주세요.
# - **msvcr100.dll** 관련 에러가 발생할 경우 http://bit.ly/3hcGImT 에서 [Microsoft Visual C++ 2010 재배포 가능 패키지]를 받아 설치해주세요.
# - 문제가 해결되지 않을 경우 바로 다음 셀의 코드를 실행해 pickle 파일로부터 Tokenizing & POS tagging이 완료된 데이터를 불러와서 2-3) 부터 실습을 시작해주세요.

# %%
#!wget https://download.java.net/java/GA/jdk16.0.2/d4a915d82b4c4fbb9bde534da945d746/7/GPL/openjdk-16.0.2_linux-x64_bin.tar.gz

# %%
# Konlpy 라이브러리가 정상적으로 작동하는지 확인합니다.
from konlpy.tag import Okt

tokenizer = Okt()
tokens = tokenizer.pos("아버지 가방에 들어가신다.", norm=True, stem=True)
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 2
#       1 # Konlpy 라이브러리가 정상적으로 작동하는지 확인합니다.
# ----> 2 from konlpy.tag import Okt
#       4 tokenizer = Okt()
#       5 tokens = tokenizer.pos("아버지 가방에 들어가신다.", norm=True, stem=True)
#
# File ~/venv/lib/python3.9/site-packages/konlpy/__init__.py:12
#       9     pass
#      11 from konlpy.jvm import init_jvm
# ---> 12 from konlpy import (
#      13     corpus,
#      14     data,
#      15     stream,
#      16     internals,
#      17     tag
#      18 )
#
# File ~/venv/lib/python3.9/site-packages/konlpy/stream/__init__.py:8
#       5 from __future__ import absolute_import
#       7 from konlpy.stream.base import BaseStreamer, KonlpyStreamerError
# ----> 8 from konlpy.stream.twitter import TwitterStreamer
#       9 from konlpy.stream.naver import NaverStreamer
#      10 from konlpy.stream.dcinside import DCInsideStreamer
#
# File ~/venv/lib/python3.9/site-packages/konlpy/stream/twitter.py:17
#      13 from konlpy.stream import BaseStreamer
#      14 from konlpy.utils import delete_links, delete_mentions, pprint
# ---> 17 class CorpusListener(tweepy.StreamListener):
#      18     def __init__(self, options, dirname, word_list):
#      19         """CorpusListener is a tweepy listener to listen on filtered list of words.
#      20
#      21         Args:
#    (...)
#      24             word_list (list): list of words
#      25         """
#
# AttributeError: module 'tweepy' has no attribute 'StreamListener'

# %%
# konlpy 설치 및 실행 불가 시, 
# 아래 코드를 통해 Tokenizing & POS tagging이 완료된 데이터를 불러오고 2-3)부터 실습을 시작해주세요.

import os, pickle 

#파이썬 변수를 pickle 파일로 저장하는 방법 
#with open('raw_pos_tagged.pkl', 'wb') as f:
#    pickle.dump(raw_pos_tagged, f)

#pickle 파일로부터 파이썬 변수를 불러오는 방법 
with open('raw_pos_tagged.pkl','rb') as f:
    data = pickle.load(f)
# -> "ran out of input" 문제 발생 시 아래 코드로 대신 실행
    
#data = [] 
#if os.path.getsize('raw_pos_tagged.pkl') > 0:      
#    with open('raw_pos_tagged.pkl', "rb") as f:
#        unpickler = pickle.Unpickler(f)
#        data = unpickler.load()    
data
# Out:
# [('[', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴시스', 'Noun'),
#  (']', 'Punctuation'),
#  ('이', 'Determiner'),
#  ('루비', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('테크노', 'Noun'),
#  ('파크', 'Noun'),
#  ('로고', 'Noun'),
#  ('.', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('이미지', 'Noun'),
#  ('=', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('테크노', 'Noun'),
#  ('파크', 'Noun'),
#  ('제공', 'Noun'),
#  (')[', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴시스', 'Noun'),
#  (']', 'Punctuation'),
#  ('이', 'Determiner'),
#  ('루비', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('테크노', 'Noun'),
#  ('파크', 'Noun'),
#  ('는', 'Josa'),
#  ("'", 'Punctuation'),
#  ('중소기업', 'Noun'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('·', 'Punctuation'),
#  ('활용', 'Noun'),
#  ('지원', 'Noun'),
#  ('사업', 'Noun'),
#  ("'", 'Punctuation'),
#  ('전국', 'Noun'),
#  ('평가', 'Noun'),
#  ('에서', 'Josa'),
#  ("'", 'Punctuation'),
#  ('우수', 'Noun'),
#  ("'", 'Punctuation'),
#  ('등급', 'Noun'),
#  ('을', 'Josa'),
#  ('받다', 'Verb'),
#  ('2일', 'Number'),
#  ('밝히다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('이', 'Noun'),
#  ('지', 'Modifier'),
#  ('원', 'Modifier'),
#  ('사업', 'Noun'),
#  ('은', 'Josa'),
#  ('중소기업', 'Noun'),
#  ('과', 'Josa'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('솔루션', 'Noun'),
#  ('을', 'Josa'),
#  ('보유', 'Noun'),
#  ('한', 'Josa'),
#  ('데이터', 'Noun'),
#  ('전', 'Modifier'),
#  ('문', 'Modifier'),
#  ('기업', 'Noun'),
#  ('을', 'Josa'),
#  ('연결하다', 'Adjective'),
#  ('기업', 'Noun'),
#  ('의', 'Josa'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('·', 'Punctuation'),
#  ('활용', 'Noun'),
#  ('을', 'Josa'),
#  ('돕다', 'Verb'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  (',', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('늘다', 'Verb'),
#  ('지난', 'Noun'),
#  ('2020년', 'Number'),
#  ('부터', 'Foreign'),
#  ('한국', 'Noun'),
#  ('지능', 'Noun'),
#  ('정보사회', 'Noun'),
#  ('진흥', 'Noun'),
#  ('원', 'Suffix'),
#  ('(', 'Punctuation'),
#  ('NIA', 'Alpha'),
#  (')', 'Punctuation'),
#  ('의', 'Noun'),
#  ('공모', 'Noun'),
#  ('에', 'Josa'),
#  ('2년', 'Number'),
#  ('연속', 'Noun'),
#  ('선정', 'Noun'),
#  ('돼다', 'Verb'),
#  ('사업', 'Noun'),
#  ('을', 'Josa'),
#  ('추진', 'Noun'),
#  ('하다', 'Verb'),
#  ('오다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('늘다', 'Verb'),
#  ('지난해', 'Noun'),
#  ('사업', 'Noun'),
#  ('비', 'Noun'),
#  ('5억원', 'Number'),
#  ('을', 'Foreign'),
#  ('들이다', 'Verb'),
#  ('전문성', 'Noun'),
#  ('부족', 'Noun'),
#  ('과', 'Josa'),
#  ('비용', 'Noun'),
#  ('문제', 'Noun'),
#  ('등', 'Noun'),
#  ('으로', 'Josa'),
#  ('빅데이터', 'Noun'),
#  ('활용', 'Noun'),
#  ('에', 'Josa'),
#  ('어려움', 'Noun'),
#  ('을', 'Josa'),
#  ('겪다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('인천', 'Noun'),
#  ('지역', 'Noun'),
#  ('28', 'Number'),
#  ('개', 'Noun'),
#  ('중소기업', 'Noun'),
#  ('에', 'Josa'),
#  ('데이터', 'Noun'),
#  ('전', 'Modifier'),
#  ('문', 'Modifier'),
#  ('기업', 'Noun'),
#  ('의', 'Josa'),
#  ('맞춤', 'Noun'),
#  ('형', 'Suffix'),
#  ('컨설팅', 'Noun'),
#  ('을', 'Josa'),
#  ('지원', 'Noun'),
#  (',', 'Punctuation'),
#  ('기업', 'Noun'),
#  ('성장', 'Noun'),
#  ('을', 'Josa'),
#  ('이끌다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('스마트', 'Noun'),
#  ('가로등', 'Noun'),
#  ('개발', 'Noun'),
#  ('업체', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('에코', 'Noun'),
#  ('란', 'Noun'),
#  ('틀다', 'Verb'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('의', 'Noun'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('·', 'Punctuation'),
#  ('활용', 'Noun'),
#  ('지원', 'Noun'),
#  ('을', 'Josa'),
#  ('바탕', 'Noun'),
#  ('으로', 'Josa'),
#  ('매출', 'Noun'),
#  ('이', 'Josa'),
#  ('두', 'Determiner'),
#  ('배', 'Noun'),
#  ('넘다', 'Verb'),
#  ('늘다', 'Verb'),
#  (',', 'Punctuation'),
#  ('유아', 'Noun'),
#  ('용품', 'Noun'),
#  ('전문', 'Noun'),
#  ('제조업', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('제', 'Modifier'),
#  ('이엠', 'Noun'),
#  ('아이', 'Noun'),
#  ('엔', 'Josa'),
#  ('티', 'Noun'),
#  ('엘', 'Josa'),
#  ('은', 'Noun'),
#  ('신제품', 'Noun'),
#  ('출시', 'Noun'),
#  ('를', 'Josa'),
#  ('앞당기다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('이사', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('서비스', 'Noun'),
#  ('제', 'Modifier'),
#  ('공기업', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('모두', 'Modifier'),
#  ('플랫폼', 'Noun'),
#  ('과', 'Josa'),
#  ('공', 'Modifier'),
#  ('기압', 'Noun'),
#  ('기기', 'Noun'),
#  ('국내', 'Noun'),
#  ('최대', 'Noun'),
#  ('제조업체', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('TPC', 'Alpha'),
#  ('메카트로닉스', 'Noun'),
#  (',', 'Punctuation'),
#  ('유압', 'Noun'),
#  ('실린더', 'Noun'),
#  ('개발', 'Noun'),
#  ('기업', 'Noun'),
#  ('우영', 'Noun'),
#  ('유압', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('은', 'Noun'),
#  ('생산', 'Noun'),
#  ('관리', 'Noun'),
#  ('효율', 'Noun'),
#  ('성', 'Suffix'),
#  ('향상', 'Noun'),
#  ('으로', 'Josa'),
#  ('시장', 'Noun'),
#  ('경쟁력', 'Noun'),
#  ('을', 'Josa'),
#  ('높이다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('운동', 'Noun'),
#  ('어플', 'Noun'),
#  ('서비스', 'Noun'),
#  ('개발', 'Noun'),
#  ('업체', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('버닛', 'Noun'),
#  ('과', 'Josa'),
#  ('AI', 'Alpha'),
#  ('(', 'Punctuation'),
#  ('인공', 'Noun'),
#  ('지능', 'Noun'),
#  (')', 'Punctuation'),
#  ('기반', 'Noun'),
#  ('폐기물', 'Noun'),
#  ('분류', 'Noun'),
#  ('시스템', 'Noun'),
#  ('개발', 'Noun'),
#  ('기업', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('에이트', 'Noun'),
#  ('테크', 'Noun'),
#  ('는', 'Josa'),
#  ('작업', 'Noun'),
#  ('효율', 'Noun'),
#  ('높이다', 'Verb'),
#  ('투자', 'Noun'),
#  ('유치', 'Noun'),
#  ('에', 'Josa'),
#  ('성공', 'Noun'),
#  (',', 'Punctuation'),
#  ('사다', 'Verb'),
#  ('확장', 'Noun'),
#  ('을', 'Josa'),
#  ('꾀', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('관계자', 'Noun'),
#  ('는', 'Josa'),
#  ('"', 'Punctuation'),
#  ('이', 'Noun'),
#  ('지', 'Modifier'),
#  ('원', 'Modifier'),
#  ('사업', 'Noun'),
#  ('을', 'Josa'),
#  ('통해', 'Noun'),
#  ('기업', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('새롭다', 'Adjective'),
#  ('비즈니스', 'Noun'),
#  ('기회', 'Noun'),
#  ('를', 'Josa'),
#  ('창', 'Noun'),
#  ('추다', 'Verb'),
#  ('경쟁력', 'Noun'),
#  ('을', 'Josa'),
#  ('키우다', 'Verb'),
#  ('나가다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('"', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('지역', 'Noun'),
#  ('기업', 'Noun'),
#  ('들', 'Suffix'),
#  ('의', 'Josa'),
#  ('데이터', 'Noun'),
#  ('활용', 'Noun'),
#  ('활성화', 'Noun'),
#  ('와', 'Josa'),
#  ('비즈니스', 'Noun'),
#  ('모델', 'Noun'),
#  ('전환', 'Noun'),
#  ('등', 'Noun'),
#  ('을', 'Josa'),
#  ('지속', 'Noun'),
#  ('하다', 'Verb'),
#  ('지원', 'Noun'),
#  ('하다', 'Verb'),
#  ('계획', 'Noun'),
#  ('"', 'Punctuation'),
#  ('이라고', 'Josa'),
#  ('말', 'Noun'),
#  ('하다', 'Verb'),
#  ('．', 'Foreign'),
#  ('[', 'Punctuation'),
#  ('KBS', 'Alpha'),
#  ('청주', 'Noun'),
#  (']', 'Punctuation'),
#  ('식품의약품안전처', 'Noun'),
#  ('는', 'Josa'),
#  ('오다', 'Verb'),
#  ('4월', 'Number'),
#  ('부터', 'Foreign'),
#  ('식', 'Noun'),
#  ('·', 'Punctuation'),
#  ('의약', 'Noun'),
#  ('데이터', 'Noun'),
#  ('를', 'Josa'),
#  ('모으다', 'Verb'),
#  ('분석', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('을', 'Josa'),
#  ('구축', 'Noun'),
#  ('하다', 'Verb'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('사업', 'Noun'),
#  ('을', 'Josa'),
#  ('추진', 'Noun'),
#  ('한', 'Josa'),
#  ('다', 'Adverb'),
#  ('고', 'Noun'),
#  ('밝히다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('유전자', 'Noun'),
#  ('[', 'Punctuation'),
#  ('게티', 'Noun'),
#  ('이미지', 'Noun'),
#  ('뱅크', 'Noun'),
#  ('제공', 'Noun'),
#  (']', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('서울', 'Noun'),
#  ('=', 'Punctuation'),
#  ('연합뉴스', 'Noun'),
#  (')', 'Punctuation'),
#  ('이정현', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('실종자', 'Noun'),
#  ('확인', 'Noun'),
#  ('시', 'Noun'),
#  ('2', 'Number'),
#  ('촌', 'Noun'),
#  ('이상', 'Noun'),
#  ('가족', 'Noun'),
#  ('간', 'Noun'),
#  ('에도', 'Josa'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('을', 'Josa'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('신', 'Modifier'),
#  ('기술', 'Noun'),
#  ('도입', 'Noun'),
#  ('이', 'Josa'),
#  ('장기', 'Noun'),
#  ('과제', 'Noun'),
#  ('로', 'Josa'),
#  ('추진', 'Noun'),
#  ('되다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('1일', 'Number'),
#  ('연합뉴스', 'Noun'),
#  ('취재', 'Noun'),
#  ('를', 'Josa'),
#  ('종합', 'Noun'),
#  ('하다', 'Verb'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('기존', 'Noun'),
#  ('1', 'Number'),
#  ('촌', 'Noun'),
#  ('끼리', 'Noun'),
#  ('만', 'Josa'),
#  ('가능하다', 'Adjective'),
#  ('가족', 'Noun'),
#  ('간', 'Noun'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('을', 'Josa'),
#  ('2', 'Number'),
#  ('촌', 'Noun'),
#  ('이상', 'Noun'),
#  ('에서도', 'Josa'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('기술', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하다', 'Verb'),
#  ('방안', 'Noun'),
#  ('을', 'Josa'),
#  ('검토', 'Noun'),
#  ('중이', 'Noun'),
#  ('다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('부모', 'Noun'),
#  ('가', 'Josa'),
#  ('고령', 'Noun'),
#  ('등', 'Noun'),
#  ('사유', 'Noun'),
#  ('로', 'Josa'),
#  ('사망', 'Noun'),
#  ('하다', 'Verb'),
#  ('경우', 'Noun'),
#  ('형제', 'Noun'),
#  ('·', 'Punctuation'),
#  ('자매', 'Noun'),
#  ('등', 'Noun'),
#  ('유전자', 'Noun'),
#  ('대조', 'Noun'),
#  ('가', 'Josa'),
#  ('필요하다', 'Adjective'),
#  ('상황', 'Noun'),
#  ('이', 'Josa'),
#  ('늘다', 'Verb'),
#  ('때문', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('형제', 'Noun'),
#  ('·', 'Punctuation'),
#  ('자매', 'Noun'),
#  ('간', 'Noun'),
#  ('유전자', 'Noun'),
#  ('대조', 'Noun'),
#  ('를', 'Josa'),
#  ('하다', 'Verb'),
#  ('일대일', 'Noun'),
#  ('이', 'Josa'),
#  ('아니다', 'Adjective'),
#  ('다대', 'Noun'),
#  ('다', 'Josa'),
#  ('데이터베이스', 'Noun'),
#  ('분석', 'Noun'),
#  ('이', 'Josa'),
#  ('필요하다', 'Adjective'),
#  (',', 'Punctuation'),
#  ('현', 'Noun'),
#  ('기술', 'Noun'),
#  ('로는', 'Josa'),
#  ('어렵다', 'Adjective'),
#  ('상황', 'Noun'),
#  ('이라', 'Josa'),
#  ('신', 'Modifier'),
#  ('기술', 'Noun'),
#  ('개발', 'Noun'),
#  ('후', 'Noun'),
#  ('국립', 'Noun'),
#  ('과학', 'Noun'),
#  ('수사', 'Noun'),
#  ('연구원', 'Noun'),
#  ('프로그램', 'Noun'),
#  ('에', 'Josa'),
#  ('탑재', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('기획재정부', 'Noun'),
#  ('를', 'Josa'),
#  ('설득', 'Noun'),
#  ('하다', 'Verb'),
#  ('최대한', 'Noun'),
#  ('관련', 'Noun'),
#  ('예산', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('해보다', 'Verb'),
#  ('입장', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('경찰청', 'Noun'),
#  ('은', 'Josa'),
#  ('장기', 'Noun'),
#  ('실종자', 'Noun'),
#  ('발견', 'Noun'),
#  ('을', 'Josa'),
#  ('위해', 'Noun'),
#  ('2004년', 'Number'),
#  ('부터', 'Foreign'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('제도', 'Noun'),
#  ('를', 'Josa'),
#  ('운용', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('실제', 'Noun'),
#  ('로', 'Josa'),
#  ('경찰청', 'Noun'),
#  ('실종', 'Noun'),
#  ('가족', 'Noun'),
#  ('지', 'Josa'),
#  ('원', 'Modifier'),
#  ('센터', 'Noun'),
#  ('에서', 'Josa'),
#  ('오랜', 'Adverb'),
#  ('세월', 'Noun'),
#  ('찾다', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하다', 'Verb'),
#  ('가족', 'Noun'),
#  ('을', 'Josa'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('으로', 'Josa'),
#  ('찾다', 'Verb'),
#  ('사례', 'Noun'),
#  ('도', 'Josa'),
#  ('점점', 'Noun'),
#  ('늘', 'Noun'),
#  ('고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('지난', 'Noun'),
#  ('7월', 'Number'),
#  ('에는', 'Foreign'),
#  ('62년', 'Number'),
#  ('전인', 'Noun'),
#  ('1959년', 'Number'),
#  ('인천', 'Noun'),
#  ('중구', 'Noun'),
#  ('배다리', 'Noun'),
#  ('시장', 'Noun'),
#  ('인근', 'Noun'),
#  ('에서', 'Josa'),
#  ('2', 'Number'),
#  ('살', 'Noun'),
#  ('터울', 'Noun'),
#  ('오빠', 'Noun'),
#  ('와', 'Josa'),
#  ('함께', 'Adverb'),
#  ('아버지', 'Noun'),
#  ('가', 'Josa'),
#  ('있다', 'Adjective'),
#  ('곳', 'Noun'),
#  ('으로', 'Josa'),
#  ('걸어가다', 'Verb'),
#  ('홀로', 'Noun'),
#  ('길', 'Noun'),
#  ('을', 'Josa'),
#  ('잃어버리다', 'Verb'),
#  ('보육원', 'Noun'),
#  ('에', 'Josa'),
#  ('보내다', 'Verb'),
#  ('뒤', 'Noun'),
#  ('하다', 'Verb'),
#  ('수녀', 'Noun'),
#  ('에게', 'Josa'),
#  ('입양', 'Noun'),
#  ('되다', 'Verb'),
#  ('60', 'Number'),
#  ('대다', 'Verb'),
#  ('여성', 'Noun'),
#  ('이', 'Josa'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('으로', 'Josa'),
#  ('오빠', 'Noun'),
#  ('와', 'Josa'),
#  ('상봉', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('당시', 'Noun'),
#  ('김창룡', 'Noun'),
#  ('경찰청장', 'Noun'),
#  ('은', 'Josa'),
#  ('"', 'Punctuation'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('제도', 'Noun'),
#  ('는', 'Josa'),
#  ('실종자', 'Noun'),
#  ('가족', 'Noun'),
#  ('의', 'Josa'),
#  ('희망', 'Noun'),
#  ('"', 'Punctuation'),
#  ('이라고', 'Josa'),
#  ('강조', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('또', 'Noun'),
#  ('실종자', 'Noun'),
#  ('신속', 'Noun'),
#  ('발견', 'Noun'),
#  ('정책', 'Noun'),
#  ('을', 'Josa'),
#  ('고도화', 'Noun'),
#  ('하다', 'Verb'),
#  ('위해', 'Noun'),
#  ('독자', 'Noun'),
#  ('적', 'Suffix'),
#  ('실종', 'Noun'),
#  ('경보', 'Noun'),
#  ('문자', 'Noun'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('구축', 'Noun'),
#  ('하다', 'Verb'),
#  ('방침', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('현재', 'Noun'),
#  ('는', 'Josa'),
#  ('행정안전부', 'Noun'),
#  ('의', 'Josa'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('사용', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('관련', 'Noun'),
#  ('업체', 'Noun'),
#  ('·', 'Punctuation'),
#  ('통신사', 'Noun'),
#  ('등', 'Noun'),
#  ('과', 'Josa'),
#  ('협의', 'Noun'),
#  ('하고', 'Josa'),
#  ('프로그램', 'Noun'),
#  ('을', 'Josa'),
#  ('마련', 'Noun'),
#  ('하다', 'Verb'),
#  ('연말', 'Noun'),
#  ('에는', 'Josa'),
#  ('독자', 'Noun'),
#  ('적', 'Suffix'),
#  ('인', 'Josa'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('구축', 'Noun'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('예상', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('차세대', 'Noun'),
#  ('실종자', 'Noun'),
#  ('정보', 'Noun'),
#  ('시스템', 'Noun'),
#  ('구축', 'Noun'),
#  ('도', 'Josa'),
#  ('추진', 'Noun'),
#  (',', 'Punctuation'),
#  ('올해', 'Noun'),
#  ('설계', 'Noun'),
#  ('를', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('예산', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('2011년', 'Number'),
#  ('부터', 'Foreign'),
#  ('써다', 'Verb'),
#  ('온', 'Noun'),
#  ('기존', 'Noun'),
#  ('실종자', 'Noun'),
#  ('정보', 'Noun'),
#  ('시스템', 'Noun'),
#  ('이', 'Josa'),
#  ('노후', 'Noun'),
#  ('화', 'Suffix'),
#  ('되다', 'Verb'),
#  ('것', 'Noun'),
#  ('을', 'Josa'),
#  ('고려', 'Noun'),
#  ('하다', 'Verb'),
#  ('GIS', 'Alpha'),
#  ('(', 'Punctuation'),
#  ('지리', 'Noun'),
#  ('정보', 'Noun'),
#  ('체계', 'Noun'),
#  (')', 'Punctuation'),
#  ('오다', 'Verb'),
#  ('영상', 'Noun'),
#  ('정보', 'Noun'),
#  ('기반', 'Noun'),
#  ('추적', 'Noun'),
#  ('시스템', 'Noun'),
#  (',', 'Punctuation'),
#  ('데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('을', 'Josa'),
#  ('통한', 'Noun'),
#  ('위험', 'Noun'),
#  ('도', 'Josa'),
#  ('판단', 'Noun'),
#  ('과', 'Josa'),
#  ('예측', 'Noun'),
#  ('모델', 'Noun'),
#  ('등', 'Noun'),
#  ('기술', 'Noun'),
#  ('을', 'Josa'),
#  ('접목', 'Noun'),
#  ('한', 'Josa'),
#  ('차세대', 'Noun'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하다', 'Verb'),
#  ('방침', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('lisa@yna.co.kr', 'Email'),
#  ('이', 'Determiner'),
#  ('달', 'Noun'),
#  ('부터', 'Josa'),
#  ('심전도', 'Noun'),
#  ('장기', 'Noun'),
#  ('검사', 'Noun'),
#  ('보험', 'Noun'),
#  ('신설', 'Noun'),
#  ('휴', 'Exclamation'),
#  ('이노', 'Noun'),
#  ('최대', 'Noun'),
#  ('4000', 'Number'),
#  ('명', 'Noun'),
#  ('규모', 'Noun'),
#  ('임', 'Noun'),
#  ('상', 'Suffix'),
#  ('계획', 'Noun'),
#  ('홀터', 'Noun'),
#  ('검사', 'Noun'),
#  ('대체', 'Noun'),
#  ('하다', 'Verb'),
#  ('AI', 'Alpha'),
#  ('진단', 'Noun'),
#  ('율', 'Noun'),
#  ('고도화', 'Noun'),
#  ('다만', 'Noun'),
#  (',', 'Punctuation'),
#  ('보험', 'Noun'),
#  ('법', 'Noun'),
#  ('개정', 'Noun'),
#  ('등', 'Noun'),
#  ('수가', 'Noun'),
#  ('지원', 'Noun'),
#  ('필요', 'Noun'),
#  ('[', 'Punctuation'),
#  ('서울', 'Noun'),
#  ('경제', 'Noun'),
#  (']', 'Punctuation'),
#  ('"', 'Punctuation'),
#  ('전국', 'Noun'),
#  ('40', 'Number'),
#  ('개', 'Noun'),
#  ('병원', 'Noun'),
#  ('에서', 'Josa'),
#  ('2000~3000', 'Number'),
#  ('명', 'Noun'),
#  ('가량', 'Noun'),
#  ('환자', 'Noun'),
#  ('를', 'Josa'),
#  ('대상', 'Noun'),
#  ('으로', 'Josa'),
#  ('6', 'Number'),
#  ('개월', 'Noun'),
#  ('내', 'Noun'),
#  ('에', 'Josa'),
#  ('임', 'Noun'),
#  ('상', 'Suffix'),
#  ('시험', 'Noun'),
#  ('을', 'Josa'),
#  ('끝내다', 'Verb'),
#  ('게', 'Noun'),
#  ('목표', 'Noun'),
#  ('이다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('심전도', 'Noun'),
#  ('검사', 'Noun'),
#  ('를', 'Josa'),
#  ('더', 'Noun'),
#  ('편리하다', 'Adjective'),
#  ('효과', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('경험', 'Noun'),
#  ('을', 'Josa'),
#  ('확대', 'Noun'),
#  ('에', 'Josa'),
#  ('빠르다', 'Adjective'),
#  ('현장', 'Noun'),
#  ('에', 'Josa'),
#  ('적용', 'Noun'),
#  ('되다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('기대하다', 'Adjective'),
#  ('."', 'Punctuation'),
#  ('이', 'Determiner'),
#  ('달', 'Noun'),
#  ('부터', 'Josa'),
#  ('의료', 'Noun'),
#  ('현장', 'Noun'),
#  ('에', 'Josa'),
#  ('원격', 'Noun'),
#  ('모니터링', 'Noun'),
#  ('이', 'Josa'),
#  ('본격', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('첫', 'Modifier'),
#  ('선', 'Noun'),
#  ('을', 'Josa'),
#  ('보이다', 'Verb'),
#  ('가운데', 'Noun'),
#  (',', 'Punctuation'),
#  ('웨어', 'Noun'),
#  ('러블', 'Noun'),
#  ('심전도', 'Noun'),
#  ('측정기', 'Noun'),
#  ("'", 'Punctuation'),
#  ('메모', 'Noun'),
#  ('패치', 'Noun'),
#  ("'", 'Punctuation'),
#  ('를', 'Noun'),
#  ('개발', 'Noun'),
#  ('한', 'Josa'),
#  ('휴', 'Exclamation'),
#  ('이노', 'Noun'),
#  ('의', 'Josa'),
#  ('길', 'Noun'),
#  ('영준', 'Noun'),
#  ('(', 'Punctuation'),
#  ('사진', 'Noun'),
#  (')', 'Punctuation'),
#  ('대표', 'Noun'),
#  ('가', 'Josa'),
#  ('자신감', 'Noun'),
#  ('있다', 'Adjective'),
#  ('출사표', 'Noun'),
#  ('를', 'Josa'),
#  ('던지다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('1일', 'Number'),
#  ('서울', 'Noun'),
#  ('청담동', 'Noun'),
#  ('휴', 'Exclamation'),
#  ('이노', 'Noun'),
#  ('본사', 'Noun'),
#  ('에서', 'Josa'),
#  ('만난', 'Noun'),
#  ('길', 'Noun'),
#  ('대표', 'Noun'),
#  ('는', 'Josa'),
#  ('"', 'Punctuation'),
#  ('기존', 'Noun'),
#  ('에', 'Josa'),
#  ('불편하다', 'Adjective'),
#  ('장비', 'Noun'),
#  ('와', 'Josa'),
#  ('달리', 'Noun'),
#  ('일상', 'Noun'),
#  ('생활', 'Noun'),
#  ('중', 'Noun'),
#  ('에', 'Josa'),
#  ('오랫동안', 'Adverb'),
#  ('크다', 'Verb'),
#  ('거부', 'Noun'),
#  ('감', 'Noun'),
#  ('없이', 'Adverb'),
#  ('착용', 'Noun'),
#  ('하다', 'Verb'),
#  ('부정맥', 'Noun'),
#  ('이나', 'Josa'),
#  ('숨다', 'Verb'),
#  ('뇌졸중', 'Noun'),
#  ('을', 'Josa'),
#  ('조기', 'Noun'),
#  ('에', 'Josa'),
#  ('진단', 'Noun'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('돕다', 'Verb'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('"\'', 'Punctuation'),
#  ('규제', 'Noun'),
#  ('샌드박스', 'Noun'),
#  ('1', 'Number'),
#  ('호', 'Noun'),
#  ("'", 'Punctuation'),
#  ('등', 'Noun'),
#  ('원격', 'Noun'),
#  ('모니터링', 'Noun'),
#  ('분야', 'Noun'),
#  ('를', 'Josa'),
#  ('7년', 'Number'),
#  ('여간', 'Foreign'),
#  ('개척', 'Noun'),
#  ('하다', 'Verb'),
#  ('온', 'Noun'),
#  ('만큼', 'Noun'),
#  ('상용', 'Noun'),
#  ('화', 'Suffix'),
#  ('에', 'Josa'),
#  ('앞장서다', 'Verb'),
#  ('것', 'Noun'),
#  ('"', 'Punctuation'),
#  ('이라고', 'Josa'),
#  ('말', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('보건복지부', 'Noun'),
#  ('가', 'Josa'),
#  ('홀터', 'Noun'),
#  ('심전도', 'Noun'),
#  ('검사', 'Noun'),
#  ('를', 'Josa'),
#  ('대체', 'Noun'),
#  ('하다', 'Verb'),
#  ('가볍다', 'Adjective'),
#  ('몸', 'Noun'),
#  ('에', 'Josa'),
#  ('착용', 'Noun'),
#  ('하다', 'Verb'),
#  ('방식', 'Noun'),
#  ('에', 'Josa'),
#  ('처음', 'Noun'),
#  ('으로', 'Josa'),
#  ('보험', 'Noun'),
#  ('을', 'Josa'),
#  ('적용', 'Noun'),
#  ('하다', 'Verb'),
#  ('올해', 'Noun'),
#  ('2월', 'Number'),
#  ('부터', 'Foreign'),
#  ('새', 'Noun'),
#  ('시장', 'Noun'),
#  ('이', 'Josa'),
#  ('열리다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('심전도', 'Noun'),
#  ('검사', 'Noun'),
#  ('를', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('홀터', 'Noun'),
#  ('기록', 'Noun'),
#  ...]

# %% [markdown]
# <br>
# <br>
#
# ## 2. 크롤링 데이터 전처리

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <br>
#
# ### 2-1) 크롤링 데이터 불러오기

# %%
df = pd.read_excel('result_220202_1834.xlsx')
df.head()
# Out:
#                                               Title                  Date  \
# 0                   인천테크노파크, 중소기업 빅데이터 지원사업 '우수' 등급  2022.02.02. 오전 10:09
# 1                           식약처, 식·의약 데이터 분석 플랫폼 구축   2022.02.01. 오전 8:28
# 2                2촌까지 가능한 유전자 분석기술 도입될까…"실종자 가족 희망"   2022.02.01. 오전 7:16
# 3  길영준 휴이노 대표 "2월 원격 모니터링 시장 첫발…최대 규모 임상 데이터 확보 목표"  2022.02.01. 오전 10:01
# 4                           “빅데이터 잘 쓰면 매출 2배도 가능해요”  2022.01.28. 오전 11:18
#
#                                              Article  \
# 0  [인천=뉴시스] 이루비 기자 =  인천테크노파크 로고. (이미지=인천테크노파크 제공...
# 1  [KBS 청주]식품의약품안전처는 오는 4월부터 식·의약 데이터를 모은 분석 플랫폼을...
# 2  유전자[게티이미지뱅크 제공]    (서울=연합뉴스) 이정현 기자 = 실종자 확인 시...
# 3  이달부터 심전도 장기검사 보험 신설휴이노 최대 4000명 규모 임상 계획홀터 검사 ...
# 4  KT, 소상공인 빅데이터 성공 사례 공유상권분석 플랫폼 ‘잘나가게’ 활용법 오픈KT...
#
#                                                  URL PressCompany
# 0  https://news.naver.com/main/read.naver?mode=LS...          뉴시스
# 1  https://news.naver.com/main/read.naver?mode=LS...          KBS
# 2  https://news.naver.com/main/read.naver?mode=LS...         연합뉴스
# 3  https://news.naver.com/main/read.naver?mode=LS...         서울경제
# 4  https://news.naver.com/main/read.naver?mode=LS...        헤럴드경제

# %%
articles = df['Article'].tolist()
len(articles)
# Out:
# 60

# %%
s = 'python is easy'
result = s.split()
print(result)

new_result = '___'.join(result)
print(new_result)
# Out:
# ['python', 'is', 'easy']
# python___is___easy

# %%
articles = ''.?(articles) # 리스트의 아이템들을 특정한 문자를 기준으로 이어 붙이기
articles[:1000]
# Out:
# '[인천=뉴시스] 이루비 기자 =  인천테크노파크 로고. (이미지=인천테크노파크 제공)[인천=뉴시스] 이루비 기자 = 인천테크노파크는 \'중소기업 빅데이터 분석·활용 지원사업\' 전국 평가에서 \'우수\' 등급을 받았다고 2일 밝혔다. 이 지원사업은 중소기업과 빅데이터 분석 솔루션을 보유한 데이터 전문기업을 연결해 기업의 빅데이터 분석·활용을 돕는 것으로, 인천TP는 지난 2020년부터 한국지능정보사회진흥원(NIA)의 공모에 2년 연속 선정돼 사업을 추진해 왔다.인천TP는 지난해 사업비 5억원을 들여 전문성 부족과 비용 문제 등으로 빅데이터 활용에 어려움을 겪고 있는 인천지역 28개 중소기업에 데이터 전문기업의 맞춤형 컨설팅을 지원, 기업 성장을 이끌었다.스마트 가로등 개발업체 ㈜에코란트는 인천TP의 빅데이터 분석·활용 지원을 바탕으로 매출이 두배 넘게 늘었으며, 유아용품 전문 제조업 ㈜제이엠아이엔티엘은 신제품 출시를 앞당겼다. 이사 플랫폼 서비스 제공기업 ㈜모두플랫폼과 공기압 기기 국내 최대 제조업체 ㈜TPC메카트로닉스, 유압 실린더 개발 기업 우영유압㈜은 생산관리 효율성 향상으로 시장경쟁력을 높였다. 운동 어플 서비스 개발업체 ㈜버닛과 AI(인공지능) 기반 폐기물 분류 시스템 개발 기업 ㈜에이트테크는 작업효율 높이면서 투자유치에 성공, 사세 확장을 꾀하고 있다.인천TP 관계자는 "이 지원사업을 통해 기업들이 새로운 비즈니스 기회를 창출하면서 경쟁력을 키워나가고 있다"며 "인천지역 기업들의 데이터 활용 활성화와 비즈니스 모델 전환 등을 지속해서 지원할 계획"이라고 말했다．[KBS 청주]식품의약품안전처는 오는 4월부터 식·의약 데이터를 모은 분석 플랫폼을 구축하기 위한 사업을 추진한다고 밝혔습니다.유전자[게티이미지뱅크 제공]    (서울=연합뉴스) 이정현 기자 = 실종자 확인 시 2촌 이상 가족 간에도 유전자 분석을 할 수 있는 신기술 도입이 장기 과제로 추진된다.    1일 연합뉴스 취재를 종합하면 경찰은 기존 1촌끼리만 가능했던 가족 간 유전자 분석을 2촌 이상에서'

# %% [markdown]
# <br>
#
# ### 2-2) 단어 정규화 및 어근화, 품사 태깅

# %%
# input data 에 품사를 태깅(tagging)합니다.
# 이 때, stem 및 norm 옵션의 기능은 다음과 같습니다.

# norm == 정규화(normalization)
# 한국어를 처리하는 예시입니닼ㅋㅋㅋ -> 한국어를 처리하는 예시입니다ㅋㅋ

# stem == 어근화(stemming)
# 한국어를 처리하는 예시입니다 ㅋㅋ -> 한국어Noun, 를Josa, 처리Noun, 하다Verb, 예시Noun, 이다Adjective, ㅋㅋKoreanParticle

from konlpy.tag import Okt

tokenizer = Okt()
raw_pos_tagged = tokenizer.pos(articles, norm=True, stem=True) # POS Tagging
raw_pos_tagged

#kernel dead : when emoji or emoticon are in data
# Out:
# [('[', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴시스', 'Noun'),
#  (']', 'Punctuation'),
#  ('이', 'Determiner'),
#  ('루비', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('테크노', 'Noun'),
#  ('파크', 'Noun'),
#  ('로고', 'Noun'),
#  ('.', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('이미지', 'Noun'),
#  ('=', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('테크노', 'Noun'),
#  ('파크', 'Noun'),
#  ('제공', 'Noun'),
#  (')[', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('=', 'Punctuation'),
#  ('뉴시스', 'Noun'),
#  (']', 'Punctuation'),
#  ('이', 'Determiner'),
#  ('루비', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('테크노', 'Noun'),
#  ('파크', 'Noun'),
#  ('는', 'Josa'),
#  ("'", 'Punctuation'),
#  ('중소기업', 'Noun'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('·', 'Punctuation'),
#  ('활용', 'Noun'),
#  ('지원', 'Noun'),
#  ('사업', 'Noun'),
#  ("'", 'Punctuation'),
#  ('전국', 'Noun'),
#  ('평가', 'Noun'),
#  ('에서', 'Josa'),
#  ("'", 'Punctuation'),
#  ('우수', 'Noun'),
#  ("'", 'Punctuation'),
#  ('등급', 'Noun'),
#  ('을', 'Josa'),
#  ('받다', 'Verb'),
#  ('2일', 'Number'),
#  ('밝히다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('이', 'Noun'),
#  ('지', 'Modifier'),
#  ('원', 'Modifier'),
#  ('사업', 'Noun'),
#  ('은', 'Josa'),
#  ('중소기업', 'Noun'),
#  ('과', 'Josa'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('솔루션', 'Noun'),
#  ('을', 'Josa'),
#  ('보유', 'Noun'),
#  ('한', 'Josa'),
#  ('데이터', 'Noun'),
#  ('전', 'Modifier'),
#  ('문', 'Modifier'),
#  ('기업', 'Noun'),
#  ('을', 'Josa'),
#  ('연결하다', 'Adjective'),
#  ('기업', 'Noun'),
#  ('의', 'Josa'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('·', 'Punctuation'),
#  ('활용', 'Noun'),
#  ('을', 'Josa'),
#  ('돕다', 'Verb'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  (',', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('늘다', 'Verb'),
#  ('지난', 'Noun'),
#  ('2020년', 'Number'),
#  ('부터', 'Foreign'),
#  ('한국', 'Noun'),
#  ('지능', 'Noun'),
#  ('정보사회', 'Noun'),
#  ('진흥', 'Noun'),
#  ('원', 'Suffix'),
#  ('(', 'Punctuation'),
#  ('NIA', 'Alpha'),
#  (')', 'Punctuation'),
#  ('의', 'Noun'),
#  ('공모', 'Noun'),
#  ('에', 'Josa'),
#  ('2년', 'Number'),
#  ('연속', 'Noun'),
#  ('선정', 'Noun'),
#  ('돼다', 'Verb'),
#  ('사업', 'Noun'),
#  ('을', 'Josa'),
#  ('추진', 'Noun'),
#  ('하다', 'Verb'),
#  ('오다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('늘다', 'Verb'),
#  ('지난해', 'Noun'),
#  ('사업', 'Noun'),
#  ('비', 'Noun'),
#  ('5억원', 'Number'),
#  ('을', 'Foreign'),
#  ('들이다', 'Verb'),
#  ('전문성', 'Noun'),
#  ('부족', 'Noun'),
#  ('과', 'Josa'),
#  ('비용', 'Noun'),
#  ('문제', 'Noun'),
#  ('등', 'Noun'),
#  ('으로', 'Josa'),
#  ('빅데이터', 'Noun'),
#  ('활용', 'Noun'),
#  ('에', 'Josa'),
#  ('어려움', 'Noun'),
#  ('을', 'Josa'),
#  ('겪다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('인천', 'Noun'),
#  ('지역', 'Noun'),
#  ('28', 'Number'),
#  ('개', 'Noun'),
#  ('중소기업', 'Noun'),
#  ('에', 'Josa'),
#  ('데이터', 'Noun'),
#  ('전', 'Modifier'),
#  ('문', 'Modifier'),
#  ('기업', 'Noun'),
#  ('의', 'Josa'),
#  ('맞춤', 'Noun'),
#  ('형', 'Suffix'),
#  ('컨설팅', 'Noun'),
#  ('을', 'Josa'),
#  ('지원', 'Noun'),
#  (',', 'Punctuation'),
#  ('기업', 'Noun'),
#  ('성장', 'Noun'),
#  ('을', 'Josa'),
#  ('이끌다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('스마트', 'Noun'),
#  ('가로등', 'Noun'),
#  ('개발', 'Noun'),
#  ('업체', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('에코', 'Noun'),
#  ('란', 'Noun'),
#  ('틀다', 'Verb'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('의', 'Noun'),
#  ('빅데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('·', 'Punctuation'),
#  ('활용', 'Noun'),
#  ('지원', 'Noun'),
#  ('을', 'Josa'),
#  ('바탕', 'Noun'),
#  ('으로', 'Josa'),
#  ('매출', 'Noun'),
#  ('이', 'Josa'),
#  ('두', 'Determiner'),
#  ('배', 'Noun'),
#  ('넘다', 'Verb'),
#  ('늘다', 'Verb'),
#  (',', 'Punctuation'),
#  ('유아', 'Noun'),
#  ('용품', 'Noun'),
#  ('전문', 'Noun'),
#  ('제조업', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('제', 'Modifier'),
#  ('이엠', 'Noun'),
#  ('아이', 'Noun'),
#  ('엔', 'Josa'),
#  ('티', 'Noun'),
#  ('엘', 'Josa'),
#  ('은', 'Noun'),
#  ('신제품', 'Noun'),
#  ('출시', 'Noun'),
#  ('를', 'Josa'),
#  ('앞당기다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('이사', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('서비스', 'Noun'),
#  ('제', 'Modifier'),
#  ('공기업', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('모두', 'Modifier'),
#  ('플랫폼', 'Noun'),
#  ('과', 'Josa'),
#  ('공', 'Modifier'),
#  ('기압', 'Noun'),
#  ('기기', 'Noun'),
#  ('국내', 'Noun'),
#  ('최대', 'Noun'),
#  ('제조업체', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('TPC', 'Alpha'),
#  ('메카트로닉스', 'Noun'),
#  (',', 'Punctuation'),
#  ('유압', 'Noun'),
#  ('실린더', 'Noun'),
#  ('개발', 'Noun'),
#  ('기업', 'Noun'),
#  ('우영', 'Noun'),
#  ('유압', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('은', 'Noun'),
#  ('생산', 'Noun'),
#  ('관리', 'Noun'),
#  ('효율', 'Noun'),
#  ('성', 'Suffix'),
#  ('향상', 'Noun'),
#  ('으로', 'Josa'),
#  ('시장', 'Noun'),
#  ('경쟁력', 'Noun'),
#  ('을', 'Josa'),
#  ('높이다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('운동', 'Noun'),
#  ('어플', 'Noun'),
#  ('서비스', 'Noun'),
#  ('개발', 'Noun'),
#  ('업체', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('버닛', 'Noun'),
#  ('과', 'Josa'),
#  ('AI', 'Alpha'),
#  ('(', 'Punctuation'),
#  ('인공', 'Noun'),
#  ('지능', 'Noun'),
#  (')', 'Punctuation'),
#  ('기반', 'Noun'),
#  ('폐기물', 'Noun'),
#  ('분류', 'Noun'),
#  ('시스템', 'Noun'),
#  ('개발', 'Noun'),
#  ('기업', 'Noun'),
#  ('㈜', 'Foreign'),
#  ('에이트', 'Noun'),
#  ('테크', 'Noun'),
#  ('는', 'Josa'),
#  ('작업', 'Noun'),
#  ('효율', 'Noun'),
#  ('높이다', 'Verb'),
#  ('투자', 'Noun'),
#  ('유치', 'Noun'),
#  ('에', 'Josa'),
#  ('성공', 'Noun'),
#  (',', 'Punctuation'),
#  ('사다', 'Verb'),
#  ('확장', 'Noun'),
#  ('을', 'Josa'),
#  ('꾀', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('TP', 'Alpha'),
#  ('관계자', 'Noun'),
#  ('는', 'Josa'),
#  ('"', 'Punctuation'),
#  ('이', 'Noun'),
#  ('지', 'Modifier'),
#  ('원', 'Modifier'),
#  ('사업', 'Noun'),
#  ('을', 'Josa'),
#  ('통해', 'Noun'),
#  ('기업', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('새롭다', 'Adjective'),
#  ('비즈니스', 'Noun'),
#  ('기회', 'Noun'),
#  ('를', 'Josa'),
#  ('창', 'Noun'),
#  ('추다', 'Verb'),
#  ('경쟁력', 'Noun'),
#  ('을', 'Josa'),
#  ('키우다', 'Verb'),
#  ('나가다', 'Verb'),
#  ('있다', 'Adjective'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('"', 'Punctuation'),
#  ('인천', 'Noun'),
#  ('지역', 'Noun'),
#  ('기업', 'Noun'),
#  ('들', 'Suffix'),
#  ('의', 'Josa'),
#  ('데이터', 'Noun'),
#  ('활용', 'Noun'),
#  ('활성화', 'Noun'),
#  ('와', 'Josa'),
#  ('비즈니스', 'Noun'),
#  ('모델', 'Noun'),
#  ('전환', 'Noun'),
#  ('등', 'Noun'),
#  ('을', 'Josa'),
#  ('지속', 'Noun'),
#  ('하다', 'Verb'),
#  ('지원', 'Noun'),
#  ('하다', 'Verb'),
#  ('계획', 'Noun'),
#  ('"', 'Punctuation'),
#  ('이라고', 'Josa'),
#  ('말', 'Noun'),
#  ('하다', 'Verb'),
#  ('．', 'Foreign'),
#  ('[', 'Punctuation'),
#  ('KBS', 'Alpha'),
#  ('청주', 'Noun'),
#  (']', 'Punctuation'),
#  ('식품의약품안전처', 'Noun'),
#  ('는', 'Josa'),
#  ('오다', 'Verb'),
#  ('4월', 'Number'),
#  ('부터', 'Foreign'),
#  ('식', 'Noun'),
#  ('·', 'Punctuation'),
#  ('의약', 'Noun'),
#  ('데이터', 'Noun'),
#  ('를', 'Josa'),
#  ('모으다', 'Verb'),
#  ('분석', 'Noun'),
#  ('플랫폼', 'Noun'),
#  ('을', 'Josa'),
#  ('구축', 'Noun'),
#  ('하다', 'Verb'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('사업', 'Noun'),
#  ('을', 'Josa'),
#  ('추진', 'Noun'),
#  ('한', 'Josa'),
#  ('다', 'Adverb'),
#  ('고', 'Noun'),
#  ('밝히다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('유전자', 'Noun'),
#  ('[', 'Punctuation'),
#  ('게티', 'Noun'),
#  ('이미지', 'Noun'),
#  ('뱅크', 'Noun'),
#  ('제공', 'Noun'),
#  (']', 'Punctuation'),
#  ('(', 'Punctuation'),
#  ('서울', 'Noun'),
#  ('=', 'Punctuation'),
#  ('연합뉴스', 'Noun'),
#  (')', 'Punctuation'),
#  ('이정현', 'Noun'),
#  ('기자', 'Noun'),
#  ('=', 'Punctuation'),
#  ('실종자', 'Noun'),
#  ('확인', 'Noun'),
#  ('시', 'Noun'),
#  ('2', 'Number'),
#  ('촌', 'Noun'),
#  ('이상', 'Noun'),
#  ('가족', 'Noun'),
#  ('간', 'Noun'),
#  ('에도', 'Josa'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('을', 'Josa'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('신', 'Modifier'),
#  ('기술', 'Noun'),
#  ('도입', 'Noun'),
#  ('이', 'Josa'),
#  ('장기', 'Noun'),
#  ('과제', 'Noun'),
#  ('로', 'Josa'),
#  ('추진', 'Noun'),
#  ('되다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('1일', 'Number'),
#  ('연합뉴스', 'Noun'),
#  ('취재', 'Noun'),
#  ('를', 'Josa'),
#  ('종합', 'Noun'),
#  ('하다', 'Verb'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('기존', 'Noun'),
#  ('1', 'Number'),
#  ('촌', 'Noun'),
#  ('끼리', 'Noun'),
#  ('만', 'Josa'),
#  ('가능하다', 'Adjective'),
#  ('가족', 'Noun'),
#  ('간', 'Noun'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('을', 'Josa'),
#  ('2', 'Number'),
#  ('촌', 'Noun'),
#  ('이상', 'Noun'),
#  ('에서도', 'Josa'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('기술', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하다', 'Verb'),
#  ('방안', 'Noun'),
#  ('을', 'Josa'),
#  ('검토', 'Noun'),
#  ('중이', 'Noun'),
#  ('다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('부모', 'Noun'),
#  ('가', 'Josa'),
#  ('고령', 'Noun'),
#  ('등', 'Noun'),
#  ('사유', 'Noun'),
#  ('로', 'Josa'),
#  ('사망', 'Noun'),
#  ('하다', 'Verb'),
#  ('경우', 'Noun'),
#  ('형제', 'Noun'),
#  ('·', 'Punctuation'),
#  ('자매', 'Noun'),
#  ('등', 'Noun'),
#  ('유전자', 'Noun'),
#  ('대조', 'Noun'),
#  ('가', 'Josa'),
#  ('필요하다', 'Adjective'),
#  ('상황', 'Noun'),
#  ('이', 'Josa'),
#  ('늘다', 'Verb'),
#  ('때문', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('형제', 'Noun'),
#  ('·', 'Punctuation'),
#  ('자매', 'Noun'),
#  ('간', 'Noun'),
#  ('유전자', 'Noun'),
#  ('대조', 'Noun'),
#  ('를', 'Josa'),
#  ('하다', 'Verb'),
#  ('일대일', 'Noun'),
#  ('이', 'Josa'),
#  ('아니다', 'Adjective'),
#  ('다대', 'Noun'),
#  ('다', 'Josa'),
#  ('데이터베이스', 'Noun'),
#  ('분석', 'Noun'),
#  ('이', 'Josa'),
#  ('필요하다', 'Adjective'),
#  (',', 'Punctuation'),
#  ('현', 'Noun'),
#  ('기술', 'Noun'),
#  ('로는', 'Josa'),
#  ('어렵다', 'Adjective'),
#  ('상황', 'Noun'),
#  ('이라', 'Josa'),
#  ('신', 'Modifier'),
#  ('기술', 'Noun'),
#  ('개발', 'Noun'),
#  ('후', 'Noun'),
#  ('국립', 'Noun'),
#  ('과학', 'Noun'),
#  ('수사', 'Noun'),
#  ('연구원', 'Noun'),
#  ('프로그램', 'Noun'),
#  ('에', 'Josa'),
#  ('탑재', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('기획재정부', 'Noun'),
#  ('를', 'Josa'),
#  ('설득', 'Noun'),
#  ('하다', 'Verb'),
#  ('최대한', 'Noun'),
#  ('관련', 'Noun'),
#  ('예산', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('해보다', 'Verb'),
#  ('입장', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('경찰청', 'Noun'),
#  ('은', 'Josa'),
#  ('장기', 'Noun'),
#  ('실종자', 'Noun'),
#  ('발견', 'Noun'),
#  ('을', 'Josa'),
#  ('위해', 'Noun'),
#  ('2004년', 'Number'),
#  ('부터', 'Foreign'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('제도', 'Noun'),
#  ('를', 'Josa'),
#  ('운용', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('실제', 'Noun'),
#  ('로', 'Josa'),
#  ('경찰청', 'Noun'),
#  ('실종', 'Noun'),
#  ('가족', 'Noun'),
#  ('지', 'Josa'),
#  ('원', 'Modifier'),
#  ('센터', 'Noun'),
#  ('에서', 'Josa'),
#  ('오랜', 'Adverb'),
#  ('세월', 'Noun'),
#  ('찾다', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하다', 'Verb'),
#  ('가족', 'Noun'),
#  ('을', 'Josa'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('으로', 'Josa'),
#  ('찾다', 'Verb'),
#  ('사례', 'Noun'),
#  ('도', 'Josa'),
#  ('점점', 'Noun'),
#  ('늘', 'Noun'),
#  ('고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('지난', 'Noun'),
#  ('7월', 'Number'),
#  ('에는', 'Foreign'),
#  ('62년', 'Number'),
#  ('전인', 'Noun'),
#  ('1959년', 'Number'),
#  ('인천', 'Noun'),
#  ('중구', 'Noun'),
#  ('배다리', 'Noun'),
#  ('시장', 'Noun'),
#  ('인근', 'Noun'),
#  ('에서', 'Josa'),
#  ('2', 'Number'),
#  ('살', 'Noun'),
#  ('터울', 'Noun'),
#  ('오빠', 'Noun'),
#  ('와', 'Josa'),
#  ('함께', 'Adverb'),
#  ('아버지', 'Noun'),
#  ('가', 'Josa'),
#  ('있다', 'Adjective'),
#  ('곳', 'Noun'),
#  ('으로', 'Josa'),
#  ('걸어가다', 'Verb'),
#  ('홀로', 'Noun'),
#  ('길', 'Noun'),
#  ('을', 'Josa'),
#  ('잃어버리다', 'Verb'),
#  ('보육원', 'Noun'),
#  ('에', 'Josa'),
#  ('보내다', 'Verb'),
#  ('뒤', 'Noun'),
#  ('하다', 'Verb'),
#  ('수녀', 'Noun'),
#  ('에게', 'Josa'),
#  ('입양', 'Noun'),
#  ('되다', 'Verb'),
#  ('60', 'Number'),
#  ('대다', 'Verb'),
#  ('여성', 'Noun'),
#  ('이', 'Josa'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('으로', 'Josa'),
#  ('오빠', 'Noun'),
#  ('와', 'Josa'),
#  ('상봉', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('당시', 'Noun'),
#  ('김창룡', 'Noun'),
#  ('경찰청장', 'Noun'),
#  ('은', 'Josa'),
#  ('"', 'Punctuation'),
#  ('유전자', 'Noun'),
#  ('분석', 'Noun'),
#  ('제도', 'Noun'),
#  ('는', 'Josa'),
#  ('실종자', 'Noun'),
#  ('가족', 'Noun'),
#  ('의', 'Josa'),
#  ('희망', 'Noun'),
#  ('"', 'Punctuation'),
#  ('이라고', 'Josa'),
#  ('강조', 'Noun'),
#  ('하다', 'Verb'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('또', 'Noun'),
#  ('실종자', 'Noun'),
#  ('신속', 'Noun'),
#  ('발견', 'Noun'),
#  ('정책', 'Noun'),
#  ('을', 'Josa'),
#  ('고도화', 'Noun'),
#  ('하다', 'Verb'),
#  ('위해', 'Noun'),
#  ('독자', 'Noun'),
#  ('적', 'Suffix'),
#  ('실종', 'Noun'),
#  ('경보', 'Noun'),
#  ('문자', 'Noun'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('구축', 'Noun'),
#  ('하다', 'Verb'),
#  ('방침', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('현재', 'Noun'),
#  ('는', 'Josa'),
#  ('행정안전부', 'Noun'),
#  ('의', 'Josa'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('사용', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('관련', 'Noun'),
#  ('업체', 'Noun'),
#  ('·', 'Punctuation'),
#  ('통신사', 'Noun'),
#  ('등', 'Noun'),
#  ('과', 'Josa'),
#  ('협의', 'Noun'),
#  ('하고', 'Josa'),
#  ('프로그램', 'Noun'),
#  ('을', 'Josa'),
#  ('마련', 'Noun'),
#  ('하다', 'Verb'),
#  ('연말', 'Noun'),
#  ('에는', 'Josa'),
#  ('독자', 'Noun'),
#  ('적', 'Suffix'),
#  ('인', 'Josa'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('구축', 'Noun'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('예상', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('차세대', 'Noun'),
#  ('실종자', 'Noun'),
#  ('정보', 'Noun'),
#  ('시스템', 'Noun'),
#  ('구축', 'Noun'),
#  ('도', 'Josa'),
#  ('추진', 'Noun'),
#  (',', 'Punctuation'),
#  ('올해', 'Noun'),
#  ('설계', 'Noun'),
#  ('를', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('예산', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('경찰', 'Noun'),
#  ('은', 'Josa'),
#  ('2011년', 'Number'),
#  ('부터', 'Foreign'),
#  ('써다', 'Verb'),
#  ('온', 'Noun'),
#  ('기존', 'Noun'),
#  ('실종자', 'Noun'),
#  ('정보', 'Noun'),
#  ('시스템', 'Noun'),
#  ('이', 'Josa'),
#  ('노후', 'Noun'),
#  ('화', 'Suffix'),
#  ('되다', 'Verb'),
#  ('것', 'Noun'),
#  ('을', 'Josa'),
#  ('고려', 'Noun'),
#  ('하다', 'Verb'),
#  ('GIS', 'Alpha'),
#  ('(', 'Punctuation'),
#  ('지리', 'Noun'),
#  ('정보', 'Noun'),
#  ('체계', 'Noun'),
#  (')', 'Punctuation'),
#  ('오다', 'Verb'),
#  ('영상', 'Noun'),
#  ('정보', 'Noun'),
#  ('기반', 'Noun'),
#  ('추적', 'Noun'),
#  ('시스템', 'Noun'),
#  (',', 'Punctuation'),
#  ('데이터', 'Noun'),
#  ('분석', 'Noun'),
#  ('을', 'Josa'),
#  ('통한', 'Noun'),
#  ('위험', 'Noun'),
#  ('도', 'Josa'),
#  ('판단', 'Noun'),
#  ('과', 'Josa'),
#  ('예측', 'Noun'),
#  ('모델', 'Noun'),
#  ('등', 'Noun'),
#  ('기술', 'Noun'),
#  ('을', 'Josa'),
#  ('접목', 'Noun'),
#  ('한', 'Josa'),
#  ('차세대', 'Noun'),
#  ('시스템', 'Noun'),
#  ('을', 'Josa'),
#  ('확보', 'Noun'),
#  ('하다', 'Verb'),
#  ('방침', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('lisa@yna.co.kr', 'Email'),
#  ('이', 'Determiner'),
#  ('달', 'Noun'),
#  ('부터', 'Josa'),
#  ('심전도', 'Noun'),
#  ('장기', 'Noun'),
#  ('검사', 'Noun'),
#  ('보험', 'Noun'),
#  ('신설', 'Noun'),
#  ('휴', 'Exclamation'),
#  ('이노', 'Noun'),
#  ('최대', 'Noun'),
#  ('4000', 'Number'),
#  ('명', 'Noun'),
#  ('규모', 'Noun'),
#  ('임', 'Noun'),
#  ('상', 'Suffix'),
#  ('계획', 'Noun'),
#  ('홀터', 'Noun'),
#  ('검사', 'Noun'),
#  ('대체', 'Noun'),
#  ('하다', 'Verb'),
#  ('AI', 'Alpha'),
#  ('진단', 'Noun'),
#  ('율', 'Noun'),
#  ('고도화', 'Noun'),
#  ('다만', 'Noun'),
#  (',', 'Punctuation'),
#  ('보험', 'Noun'),
#  ('법', 'Noun'),
#  ('개정', 'Noun'),
#  ('등', 'Noun'),
#  ('수가', 'Noun'),
#  ('지원', 'Noun'),
#  ('필요', 'Noun'),
#  ('[', 'Punctuation'),
#  ('서울', 'Noun'),
#  ('경제', 'Noun'),
#  (']', 'Punctuation'),
#  ('"', 'Punctuation'),
#  ('전국', 'Noun'),
#  ('40', 'Number'),
#  ('개', 'Noun'),
#  ('병원', 'Noun'),
#  ('에서', 'Josa'),
#  ('2000~3000', 'Number'),
#  ('명', 'Noun'),
#  ('가량', 'Noun'),
#  ('환자', 'Noun'),
#  ('를', 'Josa'),
#  ('대상', 'Noun'),
#  ('으로', 'Josa'),
#  ('6', 'Number'),
#  ('개월', 'Noun'),
#  ('내', 'Noun'),
#  ('에', 'Josa'),
#  ('임', 'Noun'),
#  ('상', 'Suffix'),
#  ('시험', 'Noun'),
#  ('을', 'Josa'),
#  ('끝내다', 'Verb'),
#  ('게', 'Noun'),
#  ('목표', 'Noun'),
#  ('이다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('심전도', 'Noun'),
#  ('검사', 'Noun'),
#  ('를', 'Josa'),
#  ('더', 'Noun'),
#  ('편리하다', 'Adjective'),
#  ('효과', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('경험', 'Noun'),
#  ('을', 'Josa'),
#  ('확대', 'Noun'),
#  ('에', 'Josa'),
#  ('빠르다', 'Adjective'),
#  ('현장', 'Noun'),
#  ('에', 'Josa'),
#  ('적용', 'Noun'),
#  ('되다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('것', 'Noun'),
#  ('으로', 'Josa'),
#  ('기대하다', 'Adjective'),
#  ('."', 'Punctuation'),
#  ('이', 'Determiner'),
#  ('달', 'Noun'),
#  ('부터', 'Josa'),
#  ('의료', 'Noun'),
#  ('현장', 'Noun'),
#  ('에', 'Josa'),
#  ('원격', 'Noun'),
#  ('모니터링', 'Noun'),
#  ('이', 'Josa'),
#  ('본격', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('첫', 'Modifier'),
#  ('선', 'Noun'),
#  ('을', 'Josa'),
#  ('보이다', 'Verb'),
#  ('가운데', 'Noun'),
#  (',', 'Punctuation'),
#  ('웨어', 'Noun'),
#  ('러블', 'Noun'),
#  ('심전도', 'Noun'),
#  ('측정기', 'Noun'),
#  ("'", 'Punctuation'),
#  ('메모', 'Noun'),
#  ('패치', 'Noun'),
#  ("'", 'Punctuation'),
#  ('를', 'Noun'),
#  ('개발', 'Noun'),
#  ('한', 'Josa'),
#  ('휴', 'Exclamation'),
#  ('이노', 'Noun'),
#  ('의', 'Josa'),
#  ('길', 'Noun'),
#  ('영준', 'Noun'),
#  ('(', 'Punctuation'),
#  ('사진', 'Noun'),
#  (')', 'Punctuation'),
#  ('대표', 'Noun'),
#  ('가', 'Josa'),
#  ('자신감', 'Noun'),
#  ('있다', 'Adjective'),
#  ('출사표', 'Noun'),
#  ('를', 'Josa'),
#  ('던지다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('1일', 'Number'),
#  ('서울', 'Noun'),
#  ('청담동', 'Noun'),
#  ('휴', 'Exclamation'),
#  ('이노', 'Noun'),
#  ('본사', 'Noun'),
#  ('에서', 'Josa'),
#  ('만난', 'Noun'),
#  ('길', 'Noun'),
#  ('대표', 'Noun'),
#  ('는', 'Josa'),
#  ('"', 'Punctuation'),
#  ('기존', 'Noun'),
#  ('에', 'Josa'),
#  ('불편하다', 'Adjective'),
#  ('장비', 'Noun'),
#  ('와', 'Josa'),
#  ('달리', 'Noun'),
#  ('일상', 'Noun'),
#  ('생활', 'Noun'),
#  ('중', 'Noun'),
#  ('에', 'Josa'),
#  ('오랫동안', 'Adverb'),
#  ('크다', 'Verb'),
#  ('거부', 'Noun'),
#  ('감', 'Noun'),
#  ('없이', 'Adverb'),
#  ('착용', 'Noun'),
#  ('하다', 'Verb'),
#  ('부정맥', 'Noun'),
#  ('이나', 'Josa'),
#  ('숨다', 'Verb'),
#  ('뇌졸중', 'Noun'),
#  ('을', 'Josa'),
#  ('조기', 'Noun'),
#  ('에', 'Josa'),
#  ('진단', 'Noun'),
#  ('하다', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('돕다', 'Verb'),
#  ('"', 'Punctuation'),
#  ('며', 'Noun'),
#  ('"\'', 'Punctuation'),
#  ('규제', 'Noun'),
#  ('샌드박스', 'Noun'),
#  ('1', 'Number'),
#  ('호', 'Noun'),
#  ("'", 'Punctuation'),
#  ('등', 'Noun'),
#  ('원격', 'Noun'),
#  ('모니터링', 'Noun'),
#  ('분야', 'Noun'),
#  ('를', 'Josa'),
#  ('7년', 'Number'),
#  ('여간', 'Foreign'),
#  ('개척', 'Noun'),
#  ('하다', 'Verb'),
#  ('온', 'Noun'),
#  ('만큼', 'Noun'),
#  ('상용', 'Noun'),
#  ('화', 'Suffix'),
#  ('에', 'Josa'),
#  ('앞장서다', 'Verb'),
#  ('것', 'Noun'),
#  ('"', 'Punctuation'),
#  ('이라고', 'Josa'),
#  ('말', 'Noun'),
#  ('하다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('보건복지부', 'Noun'),
#  ('가', 'Josa'),
#  ('홀터', 'Noun'),
#  ('심전도', 'Noun'),
#  ('검사', 'Noun'),
#  ('를', 'Josa'),
#  ('대체', 'Noun'),
#  ('하다', 'Verb'),
#  ('가볍다', 'Adjective'),
#  ('몸', 'Noun'),
#  ('에', 'Josa'),
#  ('착용', 'Noun'),
#  ('하다', 'Verb'),
#  ('방식', 'Noun'),
#  ('에', 'Josa'),
#  ('처음', 'Noun'),
#  ('으로', 'Josa'),
#  ('보험', 'Noun'),
#  ('을', 'Josa'),
#  ('적용', 'Noun'),
#  ('하다', 'Verb'),
#  ('올해', 'Noun'),
#  ('2월', 'Number'),
#  ('부터', 'Foreign'),
#  ('새', 'Noun'),
#  ('시장', 'Noun'),
#  ('이', 'Josa'),
#  ('열리다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('심전도', 'Noun'),
#  ('검사', 'Noun'),
#  ('를', 'Josa'),
#  ('위', 'Noun'),
#  ('한', 'Josa'),
#  ('홀터', 'Noun'),
#  ('기록', 'Noun'),
#  ...]

# %% [markdown]
# <br>
#
# ### 2-3) 단어 등장 빈도 카운팅

# %%
# 정규화 및 어근화를 마치고 품사 태깅까지 마친 상태에서,
# 조사, 어미, 구두점을 제외한 나머지 단어들을 모두 word_cleaned 리스트에 담습니다.
# 이 때에는 여러번 나온 단어들도 복수 허용되어 여러번 리스트에 담기게 됩니다.

# 유의미한 의미를 갖고 있지 않은 단어를 제외할 수 있습니다.
del_list = ['하다', '있다', '되다', '이다', '돼다', '않다', '그렇다', '아니다', '이렇다', '그렇다', '어떻다'] 

word_cleaned = []
for word in data: #  ('서울', 'Noun'),
    if not word[1] in ["Josa", "Eomi", "Punctuation", "Foreign"]: # Foreign == ”, “ 와 같이 제외되어야할 항목들
        if (len(word[0]) != 1) & (word[0] not in del_list): # 한 글자로 이뤄진 단어들을 제외 & 원치 않는 단어들을 제외
            word_cleaned.append(word[0])
        
word_cleaned
# Out:
# ['인천',
#  '뉴시스',
#  '루비',
#  '기자',
#  '인천',
#  '테크노',
#  '파크',
#  '로고',
#  '이미지',
#  '인천',
#  '테크노',
#  '파크',
#  '제공',
#  '인천',
#  '뉴시스',
#  '루비',
#  '기자',
#  '인천',
#  '테크노',
#  '파크',
#  '중소기업',
#  '빅데이터',
#  '분석',
#  '활용',
#  '지원',
#  '사업',
#  '전국',
#  '평가',
#  '우수',
#  '등급',
#  '받다',
#  '2일',
#  '밝히다',
#  '사업',
#  '중소기업',
#  '빅데이터',
#  '분석',
#  '솔루션',
#  '보유',
#  '데이터',
#  '기업',
#  '연결하다',
#  '기업',
#  '빅데이터',
#  '분석',
#  '활용',
#  '돕다',
#  '인천',
#  'TP',
#  '늘다',
#  '지난',
#  '2020년',
#  '한국',
#  '지능',
#  '정보사회',
#  '진흥',
#  'NIA',
#  '공모',
#  '2년',
#  '연속',
#  '선정',
#  '사업',
#  '추진',
#  '오다',
#  '인천',
#  'TP',
#  '늘다',
#  '지난해',
#  '사업',
#  '5억원',
#  '들이다',
#  '전문성',
#  '부족',
#  '비용',
#  '문제',
#  '빅데이터',
#  '활용',
#  '어려움',
#  '겪다',
#  '인천',
#  '지역',
#  '28',
#  '중소기업',
#  '데이터',
#  '기업',
#  '맞춤',
#  '컨설팅',
#  '지원',
#  '기업',
#  '성장',
#  '이끌다',
#  '스마트',
#  '가로등',
#  '개발',
#  '업체',
#  '에코',
#  '틀다',
#  '인천',
#  'TP',
#  '빅데이터',
#  '분석',
#  '활용',
#  '지원',
#  '바탕',
#  '매출',
#  '넘다',
#  '늘다',
#  '유아',
#  '용품',
#  '전문',
#  '제조업',
#  '이엠',
#  '아이',
#  '신제품',
#  '출시',
#  '앞당기다',
#  '이사',
#  '플랫폼',
#  '서비스',
#  '공기업',
#  '모두',
#  '플랫폼',
#  '기압',
#  '기기',
#  '국내',
#  '최대',
#  '제조업체',
#  'TPC',
#  '메카트로닉스',
#  '유압',
#  '실린더',
#  '개발',
#  '기업',
#  '우영',
#  '유압',
#  '생산',
#  '관리',
#  '효율',
#  '향상',
#  '시장',
#  '경쟁력',
#  '높이다',
#  '운동',
#  '어플',
#  '서비스',
#  '개발',
#  '업체',
#  '버닛',
#  'AI',
#  '인공',
#  '지능',
#  '기반',
#  '폐기물',
#  '분류',
#  '시스템',
#  '개발',
#  '기업',
#  '에이트',
#  '테크',
#  '작업',
#  '효율',
#  '높이다',
#  '투자',
#  '유치',
#  '성공',
#  '사다',
#  '확장',
#  '인천',
#  'TP',
#  '관계자',
#  '사업',
#  '통해',
#  '기업',
#  '새롭다',
#  '비즈니스',
#  '기회',
#  '추다',
#  '경쟁력',
#  '키우다',
#  '나가다',
#  '인천',
#  '지역',
#  '기업',
#  '데이터',
#  '활용',
#  '활성화',
#  '비즈니스',
#  '모델',
#  '전환',
#  '지속',
#  '지원',
#  '계획',
#  'KBS',
#  '청주',
#  '식품의약품안전처',
#  '오다',
#  '4월',
#  '의약',
#  '데이터',
#  '모으다',
#  '분석',
#  '플랫폼',
#  '구축',
#  '사업',
#  '추진',
#  '밝히다',
#  '유전자',
#  '게티',
#  '이미지',
#  '뱅크',
#  '제공',
#  '서울',
#  '연합뉴스',
#  '이정현',
#  '기자',
#  '실종자',
#  '확인',
#  '이상',
#  '가족',
#  '유전자',
#  '분석',
#  '기술',
#  '도입',
#  '장기',
#  '과제',
#  '추진',
#  '1일',
#  '연합뉴스',
#  '취재',
#  '종합',
#  '경찰',
#  '기존',
#  '끼리',
#  '가능하다',
#  '가족',
#  '유전자',
#  '분석',
#  '이상',
#  '기술',
#  '확보',
#  '방안',
#  '검토',
#  '중이',
#  '부모',
#  '고령',
#  '사유',
#  '사망',
#  '경우',
#  '형제',
#  '자매',
#  '유전자',
#  '대조',
#  '필요하다',
#  '상황',
#  '늘다',
#  '때문',
#  '형제',
#  '자매',
#  '유전자',
#  '대조',
#  '일대일',
#  '다대',
#  '데이터베이스',
#  '분석',
#  '필요하다',
#  '기술',
#  '어렵다',
#  '상황',
#  '기술',
#  '개발',
#  '국립',
#  '과학',
#  '수사',
#  '연구원',
#  '프로그램',
#  '탑재',
#  '경찰',
#  '기획재정부',
#  '설득',
#  '최대한',
#  '관련',
#  '예산',
#  '확보',
#  '해보다',
#  '입장',
#  '경찰청',
#  '장기',
#  '실종자',
#  '발견',
#  '위해',
#  '2004년',
#  '유전자',
#  '분석',
#  '제도',
#  '운용',
#  '실제',
#  '경찰청',
#  '실종',
#  '가족',
#  '센터',
#  '오랜',
#  '세월',
#  '찾다',
#  '가족',
#  '유전자',
#  '분석',
#  '찾다',
#  '사례',
#  '점점',
#  '지난',
#  '7월',
#  '62년',
#  '전인',
#  '1959년',
#  '인천',
#  '중구',
#  '배다리',
#  '시장',
#  '인근',
#  '터울',
#  '오빠',
#  '함께',
#  '아버지',
#  '걸어가다',
#  '홀로',
#  '잃어버리다',
#  '보육원',
#  '보내다',
#  '수녀',
#  '입양',
#  '60',
#  '대다',
#  '여성',
#  '유전자',
#  '분석',
#  '오빠',
#  '상봉',
#  '당시',
#  '김창룡',
#  '경찰청장',
#  '유전자',
#  '분석',
#  '제도',
#  '실종자',
#  '가족',
#  '희망',
#  '강조',
#  '경찰',
#  '실종자',
#  '신속',
#  '발견',
#  '정책',
#  '고도화',
#  '위해',
#  '독자',
#  '실종',
#  '경보',
#  '문자',
#  '시스템',
#  '구축',
#  '방침',
#  '현재',
#  '행정안전부',
#  '시스템',
#  '사용',
#  '경찰',
#  '관련',
#  '업체',
#  '통신사',
#  '협의',
#  '프로그램',
#  '마련',
#  '연말',
#  '독자',
#  '시스템',
#  '구축',
#  '예상',
#  '차세대',
#  '실종자',
#  '정보',
#  '시스템',
#  '구축',
#  '추진',
#  '올해',
#  '설계',
#  '예산',
#  '확보',
#  '경찰',
#  '2011년',
#  '써다',
#  '기존',
#  '실종자',
#  '정보',
#  '시스템',
#  '노후',
#  '고려',
#  'GIS',
#  '지리',
#  '정보',
#  '체계',
#  '오다',
#  '영상',
#  '정보',
#  '기반',
#  '추적',
#  '시스템',
#  '데이터',
#  '분석',
#  '통한',
#  '위험',
#  '판단',
#  '예측',
#  '모델',
#  '기술',
#  '접목',
#  '차세대',
#  '시스템',
#  '확보',
#  '방침',
#  'lisa@yna.co.kr',
#  '심전도',
#  '장기',
#  '검사',
#  '보험',
#  '신설',
#  '이노',
#  '최대',
#  '4000',
#  '규모',
#  '계획',
#  '홀터',
#  '검사',
#  '대체',
#  'AI',
#  '진단',
#  '고도화',
#  '다만',
#  '보험',
#  '개정',
#  '수가',
#  '지원',
#  '필요',
#  '서울',
#  '경제',
#  '전국',
#  '40',
#  '병원',
#  '2000~3000',
#  '가량',
#  '환자',
#  '대상',
#  '개월',
#  '시험',
#  '끝내다',
#  '목표',
#  '심전도',
#  '검사',
#  '편리하다',
#  '효과',
#  '경험',
#  '확대',
#  '빠르다',
#  '현장',
#  '적용',
#  '기대하다',
#  '의료',
#  '현장',
#  '원격',
#  '모니터링',
#  '본격',
#  '보이다',
#  '가운데',
#  '웨어',
#  '러블',
#  '심전도',
#  '측정기',
#  '메모',
#  '패치',
#  '개발',
#  '이노',
#  '영준',
#  '사진',
#  '대표',
#  '자신감',
#  '출사표',
#  '던지다',
#  '1일',
#  '서울',
#  '청담동',
#  '이노',
#  '본사',
#  '만난',
#  '대표',
#  '기존',
#  '불편하다',
#  '장비',
#  '달리',
#  '일상',
#  '생활',
#  '오랫동안',
#  '크다',
#  '거부',
#  '없이',
#  '착용',
#  '부정맥',
#  '숨다',
#  '뇌졸중',
#  '조기',
#  '진단',
#  '돕다',
#  '규제',
#  '샌드박스',
#  '원격',
#  '모니터링',
#  '분야',
#  '7년',
#  '개척',
#  '만큼',
#  '상용',
#  '앞장서다',
#  '보건복지부',
#  '홀터',
#  '심전도',
#  '검사',
#  '대체',
#  '가볍다',
#  '착용',
#  '방식',
#  '처음',
#  '보험',
#  '적용',
#  '올해',
#  '2월',
#  '시장',
#  '열리다',
#  '심전도',
#  '검사',
#  '홀터',
#  '기록',
#  '항목',
#  '48시간',
#  '초과',
#  '7일',
#  '이내',
#  '오다',
#  '7일',
#  '14일',
#  '이내',
#  '가다',
#  '신설',
#  '웨어',
#  '러블',
#  '심전도',
#  '측정기',
#  '장기간',
#  '착용',
#  '검사',
#  '보험',
#  '수가',
#  '적용',
#  '받다',
#  '기존',
#  '홀터',
#  '검사',
#  '24시간',
#  '동안',
#  '검사',
#  '장비',
#  '착용',
#  '다시',
#  '병원',
#  '들어오다',
#  '제거',
#  '검사',
#  '결과',
#  '확인',
#  '번거롭다',
#  '짧다',
#  '기간',
#  '부정맥',
#  '발견',
#  '단점',
#  '명확하다',
#  '따르다',
#  '여러',
#  '스케',
#  '개발',
#  '인공',
#  '지능',
#  'AI',
#  '기반',
#  '1~2',
#  '주간',
#  '원격',
#  '모니터링',
#  '심전도',
#  '데이터',
#  '분석',
#  '진단',
#  '정확도',
#  '높이다',
#  '경쟁',
#  '돌입',
#  '이노',
#  '웨어',
#  '러블',
#  '심전도',
#  '측정기',
#  '메모',
#  '패치',
#  '사진',
#  '제공',
#  '이노',
#  '이노',
#  '원격',
#  '모니터링',
#  '퍼스트',
#  '펭귄',
#  '꼽히다',
#  '대학원',
#  '생체',
#  '신호',
#  '컴퓨터',
#  '분석',
#  '연구',
#  '2014년',
#  '대표',
#  '창업',
#  '줄곧',
#  '앞서다',
#  '기술',
#  '인정받다',
#  '오다',
#  '애플',
#  '워치',
#  '3년',
#  '앞서다',
#  '2015년',
#  '심전도',
#  '측정',
#  '스마트워치',
#  '개발',
#  '지난해',
#  '서울대',
#  '함께',
#  '심전도',
#  '데이터',
#  '분석',
#  '주제',
#  '글로벌',
#  'AI',
#  '대회',
#  '차지',
#  '대표',
#  '지난해',
#  '60',
#  '규모',
#  '메모',
#  '패치',
#  '결과',
#  '기존',
#  '홀터',
#  '검사',
#  '부정맥',
#  '진단',
#  '54%',
#  '상승',
#  '절반',
#  '이상은',
#  '숨다',
#  '부정맥',
#  '추가',
#  '발견',
#  '특히',
#  '이노',
#  '2019년',
#  '정보통',
#  '기술',
#  'ICT',
#  '규제',
#  '샌드박스',
#  '호에',
#  '선정',
#  '의료',
#  '규제',
#  '허들',
#  '정면',
#  '돌파',
#  '대표',
#  '원격',
#  '의료',
#  '원격',
#  '모니터링',
#  '명확하다',
#  '구분',
#  '과거',
#  '다소',
#  '불법',
#  '회색',
#  '지대',
#  '규제',
#  '샌드박스',
#  '통해',
#  '원격',
#  '모니터링',
#  '진단',
#  '진료',
#  '돕다',
#  '도구로',
#  '가이드라인',
#  '명확하다',
#  '강조',
#  '이노',
#  '뚫다',
#  '놓다',
#  '따르다',
#  '국내',
#  '원격',
#  '모니터링',
#  '시장',
#  '치열하다',
#  '경쟁',
#  '전망',
#  '가운데',
#  '대표',
#  '이번',
#  '후발',
#  '주자',
#  '격차',
#  '벌리다',
#  '내다보다',
#  '심전도',
#  '24시간',
#  '측정',
#  '용지',
#  '2,880',
#  '분량',
#  '이르다',
#  '주치',
#  '분량',
#  '수십만',
#  '판독',
#  '고도',
#  'AI',
#  '기술',
#  '갖추다',
#  '또한',
#  '아산병원',
#  '서울대',
#  '병원',
#  '고려대병원',
#  '이대',
#  '병원',
#  '240만',
#  '건의',
#  '방대하다',
#  '데이터',
#  '확보',
#  '이번',
#  '양질',
#  '데이터',
#  '더하다',
#  'AI',
#  '고도화',
#  '가속',
#  '붙다',
#  '2월',
#  '중순',
#  '대다',
#  '주주',
#  '유한양행',
#  '000100',
#  '함께',
#  '전국',
#  '대상',
#  '메모',
#  '패치',
#  '공식',
#  '론칭할',
#  '계획',
#  '라며',
#  '동남아',
#  '미국',
#  '시장',
#  '진출',
#  '검토',
#  '중이',
#  '덧붙이다',
#  '다만',
#  '아직',
#  '규제',
#  '샌드박스',
#  '통한',
#  '개정',
#  '완비',
#  '원격',
#  '모니터링',
#  '시장',
#  '성장',
#  '한계',
#  '대표',
#  '원격',
#  '모니터링',
#  '대한',
#  '의료법',
#  '합법',
#  '화가',
#  '수년',
#  '걸리다',
#  '완료',
#  '보험',
#  '수가',
#  '적용',
#  '건강',
#  '보험',
#  '개정',
#  '얼마',
#  '시간',
#  '걸리다',
#  '미지수',
#  '라며',
#  '2월',
#  '실시',
#  '보험',
#  '적용',
#  '대면',
#  '진료',
#  '한정',
#  '장기간',
#  '원격',
#  '모니터링',
#  '확산',
#  '수가',
#  '책정',
#  '확대',
#  'KT',
#  '소상',
#  '공인',
#  '빅데이터',
#  '성공',
#  '사례',
#  '공유',
#  '상권',
#  '분석',
#  '플랫폼',
#  '잘나가다',
#  '활용',
#  '오픈',
#  'KT',
#  '가다',
#  '상공',
#  '위해',
#  '빅데이터',
#  '상권',
#  '분석',
#  '플랫폼',
#  '잘나가다',
#  '활용',
#  '알다',
#  '잘나가다',
#  '이야기',
#  '메뉴',
#  '새롭다',
#  '선보이다',
#  '28일',
#  '밝히다',
#  'KT',
#  '제공',
#  'KT',
#  '가다',
#  '상공',
#  '위해',
#  '빅데이터',
#  '상권',
#  '분석',
#  '플랫폼',
#  '잘나가다',
#  '활용',
#  '알다',
#  '잘나가다',
#  '이야기',
#  '메뉴',
#  '새롭다',
#  '선보이다',
#  '28일',
#  '밝히다',
#  '잘나가다',
#  '이야기',
#  '늘다',
#  'KT',
#  '빅데이터',
#  '상권',
#  '분석',
#  '쉬다',
#  '효과',
#  '사용',
#  '돕다',
#  '잘나가다',
#  '용법',
#  'KT',
#  '잘나가다',
#  '서비스',
#  '사용',
#  '매출',
#  '올리다',
#  '장님',
#  '실제',
#  '사례',
#  '소개',
#  '잘나가다',
#  '사장',
#  '구성',
#  '잘나가다',
#  '용법',
#  '잘나가다',
#  '상권',
#  '이해',
#  '잘나가다',
#  '배달',
#  '분석',
#  '효과',
#  '배달',
#  '전략',
#  '짜다',
#  '데이터',
#  '장사',
#  '활용',
#  '알다',
#  '콘텐츠',
#  '유튜브',
#  '영상',
#  '제공',
#  '이르다',
#  '통해',
#  '상권',
#  '영역',
#  '주변',
#  '유동',
#  '인구',
#  '매출',
#  '수준',
#  '고객',
#  '배달',
#  '수요',
#  '통계',
#  '빅데이터',
#  '정보',
#  '쉬다',
#  '이해',
#  '장사',
#  '적용',
#  '방법',
#  '잘나가다',
#  '사장',
#  '빅데이터',
#  '분석',
#  '실제',
#  '매출',
#  '올리다',
#  '장님',
#  '인터뷰',
#  '제공',
#  '인터뷰',
#  '인천',
#  '청라',
#  '초밥',
#  'KT',
#  '잘나가다',
#  '창업',
#  '상권',
#  '분석',
#  '통해',
#  '인근',
#  '수요',
#  '파악',
#  '맞춤',
#  '메뉴',
#  '개발',
#  '3000만원',
#  '매출',
#  '7000만원',
#  '끌다',
#  '올리다',
#  '사례',
#  'KT',
#  '늘다',
#  '상공',
#  '상생',
#  '위해',
#  'ESG',
#  '차원',
#  '잘나가다',
#  '이야기',
#  '포함',
#  'KT',
#  '잘나가다',
#  '서비스',
#  '무료',
#  '제공',
#  'KT',
#  ...]

# %%
# 리스트에 담긴 단어들을 대상으로 갯수를 세어,
# 단어를 key로 등장 횟수를 value로 하는 dict를 만듭니다.

word_dic = {}

for word in word_cleaned:
    if word not in word_dic:
        word_dic[word] = 1 # changed from "0" to "1"
    else:
        word_dic[word] += 1
        
word_dic
# Out:
# {'인천': 15,
#  '뉴시스': 13,
#  '루비': 2,
#  '기자': 20,
#  '테크노': 3,
#  '파크': 3,
#  '로고': 1,
#  '이미지': 12,
#  '제공': 85,
#  '중소기업': 19,
#  '빅데이터': 115,
#  '분석': 252,
#  '활용': 102,
#  '지원': 50,
#  '사업': 86,
#  '전국': 11,
#  '평가': 26,
#  '우수': 6,
#  '등급': 2,
#  '받다': 31,
#  '2일': 1,
#  '밝히다': 50,
#  '솔루션': 49,
#  '보유': 22,
#  '데이터': 538,
#  '기업': 96,
#  '연결하다': 3,
#  '돕다': 11,
#  'TP': 4,
#  '늘다': 71,
#  '지난': 20,
#  '2020년': 15,
#  '한국': 37,
#  '지능': 34,
#  '정보사회': 1,
#  '진흥': 7,
#  'NIA': 1,
#  '공모': 9,
#  '2년': 6,
#  '연속': 3,
#  '선정': 16,
#  '추진': 43,
#  '오다': 41,
#  '지난해': 60,
#  '5억원': 1,
#  '들이다': 5,
#  '전문성': 4,
#  '부족': 1,
#  '비용': 8,
#  '문제': 5,
#  '어려움': 3,
#  '겪다': 5,
#  '지역': 62,
#  '28': 1,
#  '맞춤': 20,
#  '컨설팅': 9,
#  '성장': 28,
#  '이끌다': 9,
#  '스마트': 24,
#  '가로등': 1,
#  '개발': 89,
#  '업체': 20,
#  '에코': 2,
#  '틀다': 4,
#  '바탕': 15,
#  '매출': 12,
#  '넘다': 7,
#  '유아': 2,
#  '용품': 3,
#  '전문': 15,
#  '제조업': 1,
#  '이엠': 1,
#  '아이': 1,
#  '신제품': 3,
#  '출시': 9,
#  '앞당기다': 2,
#  '이사': 19,
#  '플랫폼': 59,
#  '서비스': 154,
#  '공기업': 1,
#  '모두': 9,
#  '기압': 1,
#  '기기': 5,
#  '국내': 23,
#  '최대': 10,
#  '제조업체': 1,
#  'TPC': 1,
#  '메카트로닉스': 1,
#  '유압': 2,
#  '실린더': 1,
#  '우영': 1,
#  '생산': 3,
#  '관리': 56,
#  '효율': 11,
#  '향상': 9,
#  '시장': 59,
#  '경쟁력': 9,
#  '높이다': 15,
#  '운동': 3,
#  '어플': 1,
#  '버닛': 1,
#  'AI': 61,
#  '인공': 21,
#  '기반': 68,
#  '폐기물': 1,
#  '분류': 3,
#  '시스템': 69,
#  '에이트': 1,
#  '테크': 15,
#  '작업': 2,
#  '투자': 37,
#  '유치': 3,
#  '성공': 9,
#  '사다': 3,
#  '확장': 18,
#  '관계자': 22,
#  '통해': 83,
#  '새롭다': 35,
#  '비즈니스': 31,
#  '기회': 9,
#  '추다': 15,
#  '키우다': 6,
#  '나가다': 21,
#  '활성화': 12,
#  '모델': 22,
#  '전환': 37,
#  '지속': 21,
#  '계획': 45,
#  'KBS': 1,
#  '청주': 1,
#  '식품의약품안전처': 3,
#  '4월': 3,
#  '의약': 6,
#  '모으다': 12,
#  '구축': 46,
#  '유전자': 9,
#  '게티': 2,
#  '뱅크': 6,
#  '서울': 44,
#  '연합뉴스': 9,
#  '이정현': 1,
#  '실종자': 6,
#  '확인': 18,
#  '이상': 27,
#  '가족': 5,
#  '기술': 93,
#  '도입': 11,
#  '장기': 16,
#  '과제': 15,
#  '1일': 4,
#  '취재': 2,
#  '종합': 5,
#  '경찰': 9,
#  '기존': 23,
#  '끼리': 1,
#  '가능하다': 19,
#  '확보': 16,
#  '방안': 9,
#  '검토': 5,
#  '중이': 10,
#  '부모': 1,
#  '고령': 1,
#  '사유': 1,
#  '사망': 1,
#  '경우': 12,
#  '형제': 2,
#  '자매': 2,
#  '대조': 2,
#  '필요하다': 15,
#  '상황': 18,
#  '때문': 10,
#  '일대일': 1,
#  '다대': 1,
#  '데이터베이스': 3,
#  '어렵다': 6,
#  '국립': 2,
#  '과학': 12,
#  '수사': 1,
#  '연구원': 4,
#  '프로그램': 14,
#  '탑재': 3,
#  '기획재정부': 3,
#  '설득': 3,
#  '최대한': 2,
#  '관련': 28,
#  '예산': 10,
#  '해보다': 8,
#  '입장': 1,
#  '경찰청': 2,
#  '발견': 6,
#  '위해': 48,
#  '2004년': 1,
#  '제도': 4,
#  '운용': 5,
#  '실제': 20,
#  '실종': 2,
#  '센터': 16,
#  '오랜': 2,
#  '세월': 1,
#  '찾다': 13,
#  '사례': 27,
#  '점점': 1,
#  '7월': 5,
#  '62년': 1,
#  '전인': 1,
#  '1959년': 1,
#  '중구': 4,
#  '배다리': 1,
#  '인근': 5,
#  '터울': 1,
#  '오빠': 2,
#  '함께': 24,
#  '아버지': 1,
#  '걸어가다': 2,
#  '홀로': 2,
#  '잃어버리다': 1,
#  '보육원': 1,
#  '보내다': 1,
#  '수녀': 1,
#  '입양': 1,
#  '60': 4,
#  '대다': 25,
#  '여성': 8,
#  '상봉': 1,
#  '당시': 3,
#  '김창룡': 1,
#  '경찰청장': 1,
#  '희망': 2,
#  '강조': 13,
#  '신속': 1,
#  '정책': 21,
#  '고도화': 9,
#  '독자': 4,
#  '경보': 2,
#  '문자': 2,
#  '방침': 8,
#  '현재': 12,
#  '행정안전부': 5,
#  '사용': 24,
#  '통신사': 3,
#  '협의': 5,
#  '마련': 13,
#  '연말': 2,
#  '예상': 9,
#  '차세대': 12,
#  '정보': 44,
#  '올해': 46,
#  '설계': 6,
#  '2011년': 2,
#  '써다': 2,
#  '노후': 1,
#  '고려': 5,
#  'GIS': 1,
#  '지리': 1,
#  '체계': 16,
#  '영상': 6,
#  '추적': 5,
#  '통한': 20,
#  '위험': 8,
#  '판단': 2,
#  '예측': 30,
#  '접목': 3,
#  'lisa@yna.co.kr': 1,
#  '심전도': 11,
#  '검사': 13,
#  '보험': 38,
#  '신설': 2,
#  '이노': 8,
#  '4000': 2,
#  '규모': 7,
#  '홀터': 5,
#  '대체': 3,
#  '진단': 21,
#  '다만': 5,
#  '개정': 4,
#  '수가': 4,
#  '필요': 4,
#  '경제': 32,
#  '40': 5,
#  '병원': 13,
#  '2000~3000': 1,
#  '가량': 4,
#  '환자': 5,
#  '대상': 26,
#  '개월': 7,
#  '시험': 3,
#  '끝내다': 1,
#  '목표': 9,
#  '편리하다': 4,
#  '효과': 15,
#  '경험': 18,
#  '확대': 21,
#  '빠르다': 12,
#  '현장': 5,
#  '적용': 28,
#  '기대하다': 12,
#  '의료': 18,
#  '원격': 13,
#  '모니터링': 14,
#  '본격': 10,
#  '보이다': 20,
#  '가운데': 9,
#  '웨어': 7,
#  '러블': 7,
#  '측정기': 3,
#  '메모': 4,
#  '패치': 4,
#  '영준': 1,
#  '사진': 23,
#  '대표': 50,
#  '자신감': 1,
#  '출사표': 1,
#  '던지다': 1,
#  '청담동': 1,
#  '본사': 1,
#  '만난': 1,
#  '불편하다': 3,
#  '장비': 13,
#  '달리': 3,
#  '일상': 7,
#  '생활': 12,
#  '오랫동안': 1,
#  '크다': 44,
#  '거부': 1,
#  '없이': 5,
#  '착용': 6,
#  '부정맥': 4,
#  '숨다': 3,
#  '뇌졸중': 1,
#  '조기': 4,
#  '규제': 5,
#  '샌드박스': 4,
#  '분야': 43,
#  '7년': 1,
#  '개척': 2,
#  '만큼': 10,
#  '상용': 1,
#  '앞장서다': 3,
#  '보건복지부': 1,
#  '가볍다': 1,
#  '방식': 12,
#  '처음': 7,
#  '2월': 7,
#  '열리다': 4,
#  '기록': 16,
#  '항목': 1,
#  '48시간': 1,
#  '초과': 1,
#  '7일': 2,
#  '이내': 5,
#  '14일': 2,
#  '가다': 45,
#  '장기간': 3,
#  '24시간': 2,
#  '동안': 9,
#  '다시': 3,
#  '들어오다': 1,
#  '제거': 1,
#  '결과': 32,
#  '번거롭다': 1,
#  '짧다': 1,
#  '기간': 6,
#  '단점': 2,
#  '명확하다': 3,
#  '따르다': 30,
#  '여러': 7,
#  '스케': 6,
#  '1~2': 3,
#  '주간': 4,
#  '정확도': 2,
#  '경쟁': 7,
#  '돌입': 1,
#  '퍼스트': 1,
#  '펭귄': 1,
#  '꼽히다': 5,
#  '대학원': 1,
#  '생체': 2,
#  '신호': 2,
#  '컴퓨터': 2,
#  '연구': 14,
#  '2014년': 1,
#  '창업': 6,
#  '줄곧': 1,
#  '앞서다': 2,
#  '인정받다': 7,
#  '애플': 2,
#  '워치': 2,
#  '3년': 5,
#  '2015년': 2,
#  '측정': 4,
#  '스마트워치': 1,
#  '서울대': 2,
#  '주제': 4,
#  '글로벌': 16,
#  '대회': 11,
#  '차지': 9,
#  '54%': 2,
#  '상승': 4,
#  '절반': 2,
#  '이상은': 2,
#  '추가': 8,
#  '특히': 27,
#  '2019년': 7,
#  '정보통': 3,
#  'ICT': 7,
#  '호에': 1,
#  '허들': 1,
#  '정면': 1,
#  '돌파': 3,
#  '구분': 2,
#  '과거': 5,
#  '다소': 1,
#  '불법': 2,
#  '회색': 1,
#  '지대': 2,
#  '진료': 3,
#  '도구로': 1,
#  '가이드라인': 1,
#  '뚫다': 2,
#  '놓다': 1,
#  '치열하다': 1,
#  '전망': 16,
#  '이번': 40,
#  '후발': 1,
#  '주자': 3,
#  '격차': 1,
#  '벌리다': 1,
#  '내다보다': 3,
#  '용지': 1,
#  '2,880': 1,
#  '분량': 2,
#  '이르다': 22,
#  '주치': 1,
#  '수십만': 1,
#  '판독': 1,
#  '고도': 2,
#  '갖추다': 5,
#  '또한': 15,
#  '아산병원': 1,
#  '고려대병원': 1,
#  '이대': 1,
#  '240만': 1,
#  '건의': 3,
#  '방대하다': 2,
#  '양질': 4,
#  '더하다': 2,
#  '가속': 8,
#  '붙다': 3,
#  '중순': 1,
#  '주주': 1,
#  '유한양행': 1,
#  '000100': 1,
#  '공식': 3,
#  '론칭할': 1,
#  '라며': 25,
#  '동남아': 1,
#  '미국': 22,
#  '진출': 15,
#  '덧붙이다': 5,
#  '아직': 3,
#  '완비': 1,
#  '한계': 6,
#  '대한': 41,
#  '의료법': 1,
#  '합법': 1,
#  '화가': 1,
#  '수년': 2,
#  '걸리다': 2,
#  '완료': 2,
#  '건강': 14,
#  '얼마': 2,
#  '시간': 15,
#  '미지수': 1,
#  '실시': 3,
#  '대면': 1,
#  '한정': 1,
#  '확산': 11,
#  '책정': 1,
#  'KT': 37,
#  '소상': 2,
#  '공인': 3,
#  '공유': 9,
#  '상권': 22,
#  '잘나가다': 20,
#  '오픈': 6,
#  '상공': 6,
#  '알다': 5,
#  '이야기': 7,
#  '메뉴': 8,
#  '선보이다': 24,
#  '28일': 3,
#  '쉬다': 13,
#  '용법': 2,
#  '올리다': 11,
#  '장님': 2,
#  '소개': 4,
#  '사장': 9,
#  '구성': 12,
#  '이해': 10,
#  '배달': 5,
#  '전략': 31,
#  '짜다': 1,
#  '장사': 2,
#  '콘텐츠': 9,
#  '유튜브': 1,
#  '영역': 3,
#  '주변': 2,
#  '유동': 1,
#  '인구': 4,
#  '수준': 13,
#  '고객': 86,
#  '수요': 29,
#  '통계': 13,
#  '방법': 4,
#  '인터뷰': 4,
#  '청라': 1,
#  '초밥': 1,
#  '파악': 18,
#  '3000만원': 1,
#  '7000만원': 1,
#  '끌다': 9,
#  '상생': 1,
#  'ESG': 4,
#  '차원': 9,
#  '포함': 10,
#  '무료': 6,
#  '홈페이지': 14,
#  '회원': 7,
#  '가입': 4,
#  '최준': 1,
#  '본부': 2,
#  '본부장': 2,
#  '이용': 26,
#  '보다': 26,
#  '분들': 2,
#  '주신': 1,
#  '소중하다': 1,
#  '개선': 17,
#  '아이디어': 9,
#  '반영': 10,
#  '모든': 16,
#  '가게': 1,
#  '늘어나다': 3,
#  '김민지': 1,
#  '팁코': 10,
#  '임원': 3,
#  '인의': 1,
#  '새해': 9,
#  '엔터프라이즈': 14,
#  '코로나': 43,
#  '19': 31,
#  '주춤': 1,
#  '세계': 16,
#  '회복': 6,
#  '기대': 10,
#  '2021년': 17,
#  '바이러스': 1,
#  '등장': 6,
#  '더욱': 7,
#  '심화': 1,
#  '팬데믹': 3,
#  '공급망': 1,
#  '이슈': 4,
#  '위협': 1,
#  '각종': 6,
#  '요인': 2,
#  '인하다': 10,
#  '산업': 50,
#  '전반': 7,
#  '불확실': 3,
#  '가중': 1,
#  '급변': 1,
#  '환경': 43,
#  '디지털': 70,
#  '트랜스': 7,
#  '메이': 7,
#  '핵심': 11,
#  '역량': 20,
#  '떠오르다': 2,
#  '주재': 3,
#  '소프트웨어': 12,
#  '코리아': 6,
#  '비롯': 6,
#  '영진': 2,
#  '의견': 3,
#  '나누다': 5,
#  '전문가': 15,
#  '2022년': 11,
#  '주요': 18,
#  '화두': 2,
#  '진화': 3,
#  '인간': 5,
#  '중심': 18,
#  '부상': 4,
#  '옵스': 6,
#  'ModelOps': 1,
#  '가상화': 7,
#  '폭발': 5,
#  '현대': 7,
#  '브릭': 6,
#  '구현': 5,
#  '꼽았다': 1,
#  '투데이': 1,
#  '오늘날': 1,
#  '강화하다': 10,
#  '혁신': 51,
#  '화하다': 6,
#  '필수': 5,
#  '동력': 1,
#  '국가': 18,
#  '하나': 5,
#  '업계': 24,
#  '선도': 8,
#  '성과': 18,
#  '적극': 13,
#  '예정': 33,
#  '넬슨': 1,
#  '페트': 1,
#  '라섹': 1,
#  '최고': 12,
#  '책임자': 8,
#  'CTO': 2,
#  '사물인터넷': 1,
#  'IoT': 1,
#  '트윈': 1,
#  '머신': 9,
#  '러닝': 12,
#  'ML': 2,
#  '현실': 1,
#  'XR': 1,
#  '메타': 4,
#  '버스': 5,
#  '애플리케이션': 9,
#  '컴포저블': 1,
#  '같다': 21,
#  '통합': 31,
#  '도구': 4,
#  '접근성': 6,
#  '과학자': 3,
#  '일반': 3,
#  '사용자': 3,
#  '나아가다': 3,
#  '물론': 9,
#  '수집': 13,
#  '품질': 6,
#  '운영': 17,
#  '부가': 1,
#  '기능': 18,
#  '엔드': 2,
#  '메시': 1,
#  '마이클': 2,
#  '코넬': 2,
#  'CAO': 2,
#  '사람과': 2,
#  '협업': 21,
#  'HCAI': 3,
#  '증가': 34,
#  '들다': 11,
#  '사람': 6,
#  '전체': 14,
#  '13': 6,
#  '밀리초': 1,
#  '처리': 14,
#  '이러하다': 3,
#  '능력': 4,
#  '적응': 1,
#  '지평': 2,
#  '엔지니어링': 1,
#  '신뢰': 6,
#  '투명하다': 1,
#  '여기': 4,
#  '알고리즘': 4,
#  '테스트': 5,
#  '탐지': 2,
#  '시각': 5,
#  '훈련': 2,
#  '정성': 2,
#  '내리다': 2,
#  '의사결정': 17,
#  '도출': 6,
#  '과정': 12,
#  '불공정': 1,
#  '거나': 5,
#  '설명': 22,
#  '역시': 4,
#  '중요하다': 9,
#  '특징': 3,
#  '재택': 1,
#  '근무': 12,
#  '데브': 2,
#  '개발자': 2,
#  '사이': 9,
#  '갈등': 1,
#  '사이언스': 3,
#  '촉진': 3,
#  '하이브리드': 12,
#  '클라우드': 25,
#  '배포': 4,
#  '시나리오': 1,
#  '논의': 4,
#  '엔지니어': 3,
#  '디자인': 2,
#  '활발하다': 5,
#  '진행': 22,
#  '변화': 24,
#  '업무': 23,
#  '임시': 1,
#  'ad': 1,
#  'hoc': 1,
#  '프로세스': 6,
#  '제어': 3,
#  '집중': 11,
#  '로우': 1,
#  '코드': 7,
#  '우선': 13,
#  '요소': 1,
#  '흐름': 5,
#  '연결': 3,
#  '힘쓰다': 1,
#  '드리프트': 1,
#  '리베': 1,
#  'ROI': 1,
#  '수많다': 1,
#  '국내외': 2,
#  '홍수': 1,
#  '신속하다': 2,
#  '인사이트': 3,
#  '얻다': 6,
#  '주목': 7,
#  '물리': 1,
#  '위치': 4,
#  '형식': 4,
#  '관계없이': 1,
#  '자유롭다': 3,
#  '접근': 7,
#  '유연하다': 5,
#  '민첩하다': 1,
#  '수립': 12,
#  '시장조사': 2,
#  '기관': 24,
#  '마켓': 4,
#  '2017년': 3,
#  '15억': 1,
#  '8천만': 1,
#  '달러': 7,
#  '1조': 2,
#  '9천억': 2,
#  '41억': 1,
#  '2천만': 1,
#  '4조': 1,
#  '성장하다': 5,
#  '아태': 5,
#  '인프라': 9,
#  '측면': 3,
#  '발전': 8,
#  '거듭': 1,
#  '가장': 29,
#  '가파른': 2,
#  '토니': 1,
#  '베다': 4,
#  '파트너': 11,
#  '부문': 6,
#  '부사': 5,
#  'SVP': 1,
#  'CIO': 1,
#  '대다수': 3,
#  '아키텍처': 6,
#  '대화': 1,
#  '나은': 3,
#  '높아지다': 6,
#  '열기': 1,
#  '향후': 6,
#  '많다': 31,
#  '로드': 2,
#  '전함': 1,
#  '분산': 3,
#  '부채': 2,
#  '완화': 2,
#  '간소화': 2,
#  '조언': 1,
#  '파이낸셜뉴스': 5,
#  '부산관광공사': 1,
#  '주관': 9,
#  '공공': 40,
#  '뉴딜': 2,
#  '220만': 1,
#  '개방': 33,
#  '청년': 4,
#  '인턴': 4,
#  '65': 2,
#  '명의': 1,
#  '일자리': 2,
#  '27일': 2,
#  '공사': 3,
#  '216': 1,
#  '부산': 6,
#  '관광': 6,
#  '시설': 4,
#  '9억': 1,
#  '5000만원': 2,
#  '국비': 1,
#  '이후': 10,
#  '6월': 1,
#  '12월': 5,
#  '민간': 13,
#  '기업인': 3,
#  '레드': 1,
#  '테이블': 1,
#  '리스트': 2,
#  '스타트': 1,
#  '허브': 5,
#  '매칭': 4,
#  '수행': 10,
#  '고용': 1,
#  '수료': 1,
#  '53': 2,
#  '명과': 1,
#  '공급': 8,
#  '직접': 9,
#  '채용': 1,
#  '12': 1,
#  '월간': 4,
#  '가공': 7,
#  '기초': 8,
#  '단계': 12,
#  '교육': 18,
#  '이수': 1,
#  '해수욕장': 1,
#  '음식': 1,
#  '테마': 1,
#  '거리': 10,
#  '음식점': 1,
#  '다국어': 1,
#  '215만': 1,
#  '숙박': 1,
#  '쇼핑': 10,
#  '수상': 3,
#  '레저': 4,
#  '수중': 1,
#  '해양': 3,
#  '포츠': 1,
#  '10만': 2,
#  '관광업': 3,
#  '시민': 4,
#  '포털': 5,
#  '특화된': 5,
#  '현황': 14,
#  '트렌드': 17,
#  '이동통신': 1,
#  '신용카드': 4,
#  '관광객': 1,
#  '여행': 15,
#  '행태': 1,
#  '해내다': 4,
#  '마케팅': 12,
#  '다양하다': 51,
#  '마음껏': 1,
#  '주도하다': 6,
#  '침체': 1,
#  '살아나다': 1,
#  '노력': 11,
#  '라우': 6,
#  '성숙': 6,
#  '도르다': 7,
#  '조사': 13,
#  '보고서': 4,
#  '24일': 6,
#  '발표': 14,
#  '벤슨본': 1,
#  '협력': 16,
#  '발간': 3,
#  '상관관계': 1,
#  '기획': 5,
#  '미치다': 3,
#  '영향': 9,
#  '응답': 10,
#  '전세계': 2,
#  '고위': 6,
#  '자다': 7,
#  '최소': 2,
#  '1년': 7,
#  '성숙하다': 2,
#  '조직': 14,
#  '평균': 30,
#  '5.97%': 1,
#  '높다': 39,
#  '이익': 2,
#  '자의': 5,
#  '96%': 2,
#  '긍정': 1,
#  '3분': 1,
#  '64%': 1,
#  '시작': 20,
#  '복원력': 2,
#  '시키다': 15,
#  '연간': 7,
#  '수익': 5,
#  '밀접하다': 1,
#  '관계성': 1,
#  '나타내다': 6,
#  '매우': 4,
#  '92%': 2,
#  '갖다': 3,
#  '76%': 1,
#  '만족도': 1,
#  '매년': 7,
#  '600만': 1,
#  '잃다': 1,
#  '16': 2,
#  '수치': 7,
#  'IT': 7,
#  '멀티': 10,
#  '시사': 1,
#  '70%': 1,
#  '툴로': 1,
#  '52%': 1,
#  '18': 3,
#  '36%': 1,
#  '대부분': 4,
#  '완전하다': 1,
#  '참여': 18,
#  '88%': 1,
#  '라이프': 5,
#  '사이클': 4,
#  '걸치다': 6,
#  '안전하다': 2,
#  '중앙': 6,
#  '보안': 9,
#  '규정': 1,
#  '준수': 1,
#  '거버넌스': 2,
#  '12%': 1,
#  '상당': 3,
#  '수의': 2,
#  '중요성': 6,
#  '63%': 1,
#  '느끼다': 3,
#  '91%': 1,
#  '동의': 4,
#  '설문': 2,
#  '충분하다': 3,
#  '38만': 1,
#  '4천': 1,
#  '952달러': 1,
#  '손실': 2,
#  '입다': 1,
#  '통신': 8,
#  '661만': 1,
#  '7천': 1,
#  '348달러': 1,
#  '현명하다': 1,
#  '엄격하다': 2,
#  '요구사항': 1,
#  '충족': 3,
#  '인력': 9,
#  '43.07%': 1,
#  '투자가': 4,
#  '이뤄지다': 2,
#  '79%': 2,
#  '성능': 3,
#  '44%': 1,
#  '선호': 8,
#  '장소': 4,
#  '안정': 1,
#  '그리고': 5,
#  '프레': 2,
#  '미스': 2,
#  '일이': 3,
#  '가치': 13,
#  '90%': 2,
#  '삼다': 2,
#  '89%': 1,
#  '증대': 2,
#  'DEI': 3,
#  '다양성': 2,
#  '용성': 1,
#  '다른': 8,
#  '이어지다': 6,
#  '나타나다': 20,
#  '95%': 4,
#  '실현': 4,
#  '기여': 6,
#  '직원': 3,
#  '유지': 3,
#  '독려': 1,
#  '도도': 2,
#  '마크': 1,
#  '밉다': 5,
#  '레프': 1,
#  '총괄': 6,
#  '의사': 4,
#  '결정': 2,
#  '생각': 7,
#  '이해도': 2,
#  '보여주다': 11,
#  '절감': 1,
#  '자산': 35,
#  '임재범': 1,
#  '고급': 1,
#  '능통하다': 1,
#  ...}

# %%
# # 위 cell에서의 작업과 동일한 작업을 아래의 코드로 대체할 수 있습니다.

# from collections import Counter
# result = Counter(word_cleaned)
# word_dic = dict(result)
# word_dic

# %% [markdown]
# #### -> You can preceed to [3. 워드클라우드 만들기] from here.

# %%
#word_dic.items()
# Out:
# dict_items([('인천', 15), ('뉴시스', 13), ('루비', 2), ('기자', 20), ('테크노', 3), ('파크', 3), ('로고', 1), ('이미지', 12), ('제공', 85), ('중소기업', 19), ('빅데이터', 115), ('분석', 252), ('활용', 102), ('지원', 50), ('사업', 86), ('전국', 11), ('평가', 26), ('우수', 6), ('등급', 2), ('받다', 31), ('2일', 1), ('밝히다', 50), ('솔루션', 49), ('보유', 22), ('데이터', 538), ('기업', 96), ('연결하다', 3), ('돕다', 11), ('TP', 4), ('늘다', 71), ('지난', 20), ('2020년', 15), ('한국', 37), ('지능', 34), ('정보사회', 1), ('진흥', 7), ('NIA', 1), ('공모', 9), ('2년', 6), ('연속', 3), ('선정', 16), ('추진', 43), ('오다', 41), ('지난해', 60), ('5억원', 1), ('들이다', 5), ('전문성', 4), ('부족', 1), ('비용', 8), ('문제', 5), ('어려움', 3), ('겪다', 5), ('지역', 62), ('28', 1), ('맞춤', 20), ('컨설팅', 9), ('성장', 28), ('이끌다', 9), ('스마트', 24), ('가로등', 1), ('개발', 89), ('업체', 20), ('에코', 2), ('틀다', 4), ('바탕', 15), ('매출', 12), ('넘다', 7), ('유아', 2), ('용품', 3), ('전문', 15), ('제조업', 1), ('이엠', 1), ('아이', 1), ('신제품', 3), ('출시', 9), ('앞당기다', 2), ('이사', 19), ('플랫폼', 59), ('서비스', 154), ('공기업', 1), ('모두', 9), ('기압', 1), ('기기', 5), ('국내', 23), ('최대', 10), ('제조업체', 1), ('TPC', 1), ('메카트로닉스', 1), ('유압', 2), ('실린더', 1), ('우영', 1), ('생산', 3), ('관리', 56), ('효율', 11), ('향상', 9), ('시장', 59), ('경쟁력', 9), ('높이다', 15), ('운동', 3), ('어플', 1), ('버닛', 1), ('AI', 61), ('인공', 21), ('기반', 68), ('폐기물', 1), ('분류', 3), ('시스템', 69), ('에이트', 1), ('테크', 15), ('작업', 2), ('투자', 37), ('유치', 3), ('성공', 9), ('사다', 3), ('확장', 18), ('관계자', 22), ('통해', 83), ('새롭다', 35), ('비즈니스', 31), ('기회', 9), ('추다', 15), ('키우다', 6), ('나가다', 21), ('활성화', 12), ('모델', 22), ('전환', 37), ('지속', 21), ('계획', 45), ('KBS', 1), ('청주', 1), ('식품의약품안전처', 3), ('4월', 3), ('의약', 6), ('모으다', 12), ('구축', 46), ('유전자', 9), ('게티', 2), ('뱅크', 6), ('서울', 44), ('연합뉴스', 9), ('이정현', 1), ('실종자', 6), ('확인', 18), ('이상', 27), ('가족', 5), ('기술', 93), ('도입', 11), ('장기', 16), ('과제', 15), ('1일', 4), ('취재', 2), ('종합', 5), ('경찰', 9), ('기존', 23), ('끼리', 1), ('가능하다', 19), ('확보', 16), ('방안', 9), ('검토', 5), ('중이', 10), ('부모', 1), ('고령', 1), ('사유', 1), ('사망', 1), ('경우', 12), ('형제', 2), ('자매', 2), ('대조', 2), ('필요하다', 15), ('상황', 18), ('때문', 10), ('일대일', 1), ('다대', 1), ('데이터베이스', 3), ('어렵다', 6), ('국립', 2), ('과학', 12), ('수사', 1), ('연구원', 4), ('프로그램', 14), ('탑재', 3), ('기획재정부', 3), ('설득', 3), ('최대한', 2), ('관련', 28), ('예산', 10), ('해보다', 8), ('입장', 1), ('경찰청', 2), ('발견', 6), ('위해', 48), ('2004년', 1), ('제도', 4), ('운용', 5), ('실제', 20), ('실종', 2), ('센터', 16), ('오랜', 2), ('세월', 1), ('찾다', 13), ('사례', 27), ('점점', 1), ('7월', 5), ('62년', 1), ('전인', 1), ('1959년', 1), ('중구', 4), ('배다리', 1), ('인근', 5), ('터울', 1), ('오빠', 2), ('함께', 24), ('아버지', 1), ('걸어가다', 2), ('홀로', 2), ('잃어버리다', 1), ('보육원', 1), ('보내다', 1), ('수녀', 1), ('입양', 1), ('60', 4), ('대다', 25), ('여성', 8), ('상봉', 1), ('당시', 3), ('김창룡', 1), ('경찰청장', 1), ('희망', 2), ('강조', 13), ('신속', 1), ('정책', 21), ('고도화', 9), ('독자', 4), ('경보', 2), ('문자', 2), ('방침', 8), ('현재', 12), ('행정안전부', 5), ('사용', 24), ('통신사', 3), ('협의', 5), ('마련', 13), ('연말', 2), ('예상', 9), ('차세대', 12), ('정보', 44), ('올해', 46), ('설계', 6), ('2011년', 2), ('써다', 2), ('노후', 1), ('고려', 5), ('GIS', 1), ('지리', 1), ('체계', 16), ('영상', 6), ('추적', 5), ('통한', 20), ('위험', 8), ('판단', 2), ('예측', 30), ('접목', 3), ('lisa@yna.co.kr', 1), ('심전도', 11), ('검사', 13), ('보험', 38), ('신설', 2), ('이노', 8), ('4000', 2), ('규모', 7), ('홀터', 5), ('대체', 3), ('진단', 21), ('다만', 5), ('개정', 4), ('수가', 4), ('필요', 4), ('경제', 32), ('40', 5), ('병원', 13), ('2000~3000', 1), ('가량', 4), ('환자', 5), ('대상', 26), ('개월', 7), ('시험', 3), ('끝내다', 1), ('목표', 9), ('편리하다', 4), ('효과', 15), ('경험', 18), ('확대', 21), ('빠르다', 12), ('현장', 5), ('적용', 28), ('기대하다', 12), ('의료', 18), ('원격', 13), ('모니터링', 14), ('본격', 10), ('보이다', 20), ('가운데', 9), ('웨어', 7), ('러블', 7), ('측정기', 3), ('메모', 4), ('패치', 4), ('영준', 1), ('사진', 23), ('대표', 50), ('자신감', 1), ('출사표', 1), ('던지다', 1), ('청담동', 1), ('본사', 1), ('만난', 1), ('불편하다', 3), ('장비', 13), ('달리', 3), ('일상', 7), ('생활', 12), ('오랫동안', 1), ('크다', 44), ('거부', 1), ('없이', 5), ('착용', 6), ('부정맥', 4), ('숨다', 3), ('뇌졸중', 1), ('조기', 4), ('규제', 5), ('샌드박스', 4), ('분야', 43), ('7년', 1), ('개척', 2), ('만큼', 10) ...

# %%
# lambda 함수를 활용하여,
# 앞서 만든 dict를 item 단위(tuple)로 꺼내어, tuple(x)의 value(x[1])를 기준으로 하여 내림차순(reverse=True) 정렬합니다.

sorted_word_dic = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
sorted_word_dic
# Out:
# [('데이터', 538),
#  ('분석', 252),
#  ('서비스', 154),
#  ('빅데이터', 115),
#  ('활용', 102),
#  ('기업', 96),
#  ('기술', 93),
#  ('개발', 89),
#  ('사업', 86),
#  ('고객', 86),
#  ('제공', 85),
#  ('통해', 83),
#  ('늘다', 71),
#  ('디지털', 70),
#  ('시스템', 69),
#  ('기반', 68),
#  ('지역', 62),
#  ('AI', 61),
#  ('금융', 61),
#  ('지난해', 60),
#  ('플랫폼', 59),
#  ('시장', 59),
#  ('관리', 56),
#  ('혁신', 51),
#  ('다양하다', 51),
#  ('지원', 50),
#  ('밝히다', 50),
#  ('대표', 50),
#  ('산업', 50),
#  ('솔루션', 49),
#  ('카드', 49),
#  ('위해', 48),
#  ('구축', 46),
#  ('올해', 46),
#  ('계획', 45),
#  ('가다', 45),
#  ('마이', 45),
#  ('서울', 44),
#  ('정보', 44),
#  ('크다', 44),
#  ('추진', 43),
#  ('분야', 43),
#  ('코로나', 43),
#  ('환경', 43),
#  ('오다', 41),
#  ('대한', 41),
#  ('이번', 40),
#  ('공공', 40),
#  ('상품', 40),
#  ('높다', 39),
#  ('보험', 38),
#  ('범죄', 38),
#  ('한국', 37),
#  ('투자', 37),
#  ('전환', 37),
#  ('KT', 37),
#  ('새롭다', 35),
#  ('자산', 35),
#  ('지능', 34),
#  ('증가', 34),
#  ('예정', 33),
#  ('개방', 33),
#  ('경제', 32),
#  ('결과', 32),
#  ('받다', 31),
#  ('비즈니스', 31),
#  ('전략', 31),
#  ('19', 31),
#  ('통합', 31),
#  ('많다', 31),
#  ('LG', 31),
#  ('예측', 30),
#  ('따르다', 30),
#  ('평균', 30),
#  ('미래', 30),
#  ('정부', 30),
#  ('수요', 29),
#  ('가장', 29),
#  ('식품', 29),
#  ('성장', 28),
#  ('관련', 28),
#  ('적용', 28),
#  ('가격', 28),
#  ('이상', 27),
#  ('사례', 27),
#  ('특히', 27),
#  ('평가', 26),
#  ('대상', 26),
#  ('이용', 26),
#  ('보다', 26),
#  ('소비', 26),
#  ('신년사', 26),
#  ('비트코인', 26),
#  ('대다', 25),
#  ('라며', 25),
#  ('클라우드', 25),
#  ('스마트', 24),
#  ('함께', 24),
#  ('사용', 24),
#  ('선보이다', 24),
#  ('업계', 24),
#  ('변화', 24),
#  ('기관', 24),
#  ('대비', 24),
#  ('국내', 23),
#  ('기존', 23),
#  ('사진', 23),
#  ('업무', 23),
#  ('회사', 23),
#  ('행정', 23),
#  ('축구', 23),
#  ('보유', 22),
#  ('관계자', 22),
#  ('모델', 22),
#  ('이르다', 22),
#  ('미국', 22),
#  ('상권', 22),
#  ('설명', 22),
#  ('진행', 22),
#  ('국민', 22),
#  ('인공', 21),
#  ('나가다', 21),
#  ('지속', 21),
#  ('정책', 21),
#  ('진단', 21),
#  ('확대', 21),
#  ('같다', 21),
#  ('협업', 21),
#  ('네이버', 21),
#  ('선수', 21),
#  ('하락', 21),
#  ('기자', 20),
#  ('지난', 20),
#  ('맞춤', 20),
#  ('업체', 20),
#  ('실제', 20),
#  ('통한', 20),
#  ('보이다', 20),
#  ('잘나가다', 20),
#  ('역량', 20),
#  ('시작', 20),
#  ('나타나다', 20),
#  ('중소기업', 19),
#  ('이사', 19),
#  ('가능하다', 19),
#  ('DB', 19),
#  ('그룹', 19),
#  ('확장', 18),
#  ('확인', 18),
#  ('상황', 18),
#  ('경험', 18),
#  ('의료', 18),
#  ('파악', 18),
#  ('주요', 18),
#  ('중심', 18),
#  ('국가', 18),
#  ('성과', 18),
#  ('기능', 18),
#  ('교육', 18),
#  ('참여', 18),
#  ('발생', 18),
#  ('CDO', 18),
#  ('투자자', 18),
#  ('개선', 17),
#  ('2021년', 17),
#  ('운영', 17),
#  ('의사결정', 17),
#  ('트렌드', 17),
#  ('침입', 17),
#  ('대응', 17),
#  ('최근', 17),
#  ('결제', 17),
#  ('유플러스', 17),
#  ('워드', 17),
#  ('시대', 17),
#  ('선정', 16),
#  ('장기', 16),
#  ('확보', 16),
#  ('센터', 16),
#  ('체계', 16),
#  ('기록', 16),
#  ('글로벌', 16),
#  ('전망', 16),
#  ('모든', 16),
#  ('세계', 16),
#  ('협력', 16),
#  ('온라인', 16),
#  ('강화', 16),
#  ('사기', 16),
#  ('포인트', 16),
#  ('커비', 16),
#  ('인천', 15),
#  ('2020년', 15),
#  ('바탕', 15),
#  ('전문', 15),
#  ('높이다', 15),
#  ('테크', 15),
#  ('추다', 15),
#  ('과제', 15),
#  ('필요하다', 15),
#  ('효과', 15),
#  ('또한', 15),
#  ('진출', 15),
#  ('시간', 15),
#  ('전문가', 15),
#  ('여행', 15),
#  ('시키다', 15),
#  ('매장', 15),
#  ('활동', 15),
#  ('롯데', 15),
#  ('제품', 15),
#  ('가축', 15),
#  ('스타트업', 15),
#  ('위원회', 15),
#  ('발굴', 15),
#  ('주문', 15),
#  ('비중', 15),
#  ('프로그램', 14),
#  ('모니터링', 14),
#  ('연구', 14),
#  ('건강', 14),
#  ('홈페이지', 14),
#  ('엔터프라이즈', 14),
#  ('전체', 14),
#  ('처리', 14),
#  ('현황', 14),
#  ('발표', 14),
#  ('조직', 14),
#  ('무인', 14),
#  ('많이', 14),
#  ('오늘', 14),
#  ('이용자', 14),
#  ('유통', 14),
#  ('하나카드', 14),
#  ('맞다', 14),
#  ('역할', 14),
#  ('공동', 14),
#  ('드림', 14),
#  ('TACO', 14),
#  ('강남', 14),
#  ('배송', 14),
#  ('뉴시스', 13),
#  ('찾다', 13),
#  ('강조', 13),
#  ('마련', 13),
#  ('검사', 13),
#  ('병원', 13),
#  ('원격', 13),
#  ('장비', 13),
#  ('쉬다', 13),
#  ('수준', 13),
#  ('통계', 13),
#  ('적극', 13),
#  ('수집', 13),
#  ('우선', 13),
#  ('민간', 13),
#  ('조사', 13),
#  ('가치', 13),
#  ('영국', 13),
#  ('비교', 13),
#  ('의미', 13),
#  ('21일', 13),
#  ('없다', 13),
#  ('우리', 13),
#  ('다이어트', 13),
#  ('신한은행', 13),
#  ('이미지', 12),
#  ('매출', 12),
#  ('활성화', 12),
#  ('모으다', 12),
#  ('경우', 12),
#  ('과학', 12),
#  ('현재', 12),
#  ('차세대', 12),
#  ('빠르다', 12),
#  ('기대하다', 12),
#  ('생활', 12),
#  ('방식', 12),
#  ('구성', 12),
#  ('소프트웨어', 12),
#  ('최고', 12),
#  ('러닝', 12),
#  ('과정', 12),
#  ('근무', 12),
#  ('하이브리드', 12),
#  ('수립', 12),
#  ('단계', 12),
#  ('마케팅', 12),
#  ('관계', 12),
#  ('자동차', 12),
#  ('자체', 12),
#  ('지역별', 12),
#  ('관심', 12),
#  ('20일', 12),
#  ('브릭스', 12),
#  ('바이', 12),
#  ('재정', 12),
#  ('공모전', 12),
#  ('자율', 12),
#  ('라이즈', 12),
#  ('SKT', 12),
#  ('여가', 12),
#  ('프리미엄', 12),
#  ('화장품', 12),
#  ('스포츠', 12),
#  ('코인', 12),
#  ('전국', 11),
#  ('돕다', 11),
#  ('효율', 11),
#  ('도입', 11),
#  ('심전도', 11),
#  ('대회', 11),
#  ('확산', 11),
#  ('올리다', 11),
#  ('핵심', 11),
#  ('2022년', 11),
#  ('들다', 11),
#  ('집중', 11),
#  ('파트너', 11),
#  ('노력', 11),
#  ('보여주다', 11),
#  ('나서다', 11),
#  ('자동', 11),
#  ('개인', 11),
#  ('노하우', 11),
#  ('은행', 11),
#  ('질병', 11),
#  ('한다는', 11),
#  ('기준', 11),
#  ('DX', 11),
#  ('청약', 11),
#  ('언급', 11),
#  ('3만', 11),
#  ('교통사고', 11),
#  ('최대', 10),
#  ('중이', 10),
#  ('때문', 10),
#  ('예산', 10),
#  ('본격', 10),
#  ('만큼', 10),
#  ('이해', 10),
#  ('포함', 10),
#  ('반영', 10),
#  ('팁코', 10),
#  ('기대', 10),
#  ('인하다', 10),
#  ('강화하다', 10),
#  ('이후', 10),
#  ('수행', 10),
#  ('거리', 10),
#  ('쇼핑', 10),
#  ('응답', 10),
#  ('멀티', 10),
#  ('자료', 10),
#  ('한편', 10),
#  ('구매', 10),
#  ('원하다', 10),
#  ('패턴', 10),
#  ('채널', 10),
#  ('지표', 10),
#  ('유행', 10),
#  ('인증', 10),
#  ('지도', 10),
#  ('내용', 10),
#  ('루커스', 10),
#  ('레이크', 10),
#  ('정도', 10),
#  ('안전', 10),
#  ('부처', 10),
#  ('만들다', 10),
#  ('친환경', 10),
#  ('브레인', 10),
#  ('지자체', 10),
#  ('이커머스', 10),
#  ('주행', 10),
#  ('사업자', 10),
#  ('강북', 10),
#  ('아마추어', 10),
#  ('유비스랩', 10),
#  ('가상', 10),
#  ('고래', 10),
#  ('공모', 9),
#  ('컨설팅', 9),
#  ('이끌다', 9),
#  ('출시', 9),
#  ('모두', 9),
#  ('향상', 9),
#  ('경쟁력', 9),
#  ('성공', 9),
#  ('기회', 9),
#  ('유전자', 9),
#  ('연합뉴스', 9),
#  ('경찰', 9),
#  ('방안', 9),
#  ('고도화', 9),
#  ('예상', 9),
#  ('목표', 9),
#  ('가운데', 9),
#  ('동안', 9),
#  ('차지', 9),
#  ('공유', 9),
#  ('사장', 9),
#  ('콘텐츠', 9),
#  ('끌다', 9),
#  ('차원', 9),
#  ('아이디어', 9),
#  ('새해', 9),
#  ('머신', 9),
#  ('애플리케이션', 9),
#  ('물론', 9),
#  ('중요하다', 9),
#  ('사이', 9),
#  ('인프라', 9),
#  ('주관', 9),
#  ('직접', 9),
#  ('영향', 9),
#  ('보안', 9),
#  ('인력', 9),
#  ('별로', 9),
#  ('설치', 9),
#  ('CCTV', 9),
#  ('즉시', 9),
#  ('최초', 9),
#  ('아우르다', 9),
#  ('해결', 9),
#  ('파다', 9),
#  ('신규', 9),
#  ('해외', 9),
#  ('거래', 9),
#  ('바스', 9),
#  ('시행', 9),
#  ('도움', 9),
#  ('담당', 9),
#  ('20', 9),
#  ('뉴스', 9),
#  ('대통령', 9),
#  ('SK', 9),
#  ('학생', 9),
#  ('분과', 9),
#  ('CJ', 9),
#  ('거래소', 9),
#  ('비용', 8),
#  ('해보다', 8),
#  ('여성', 8),
#  ('방침', 8),
#  ('위험', 8),
#  ('이노', 8),
#  ('추가', 8),
#  ('가속', 8),
#  ('메뉴', 8),
#  ('선도', 8),
#  ('책임자', 8),
#  ('발전', 8),
#  ('공급', 8),
#  ('기초', 8),
#  ('통신', 8),
#  ('선호', 8),
#  ('다른', 8),
#  ('심사', 8),
#  ('감소', 8),
#  ('업종', 8),
#  ('사회', 8),
#  ('맞추다', 8),
#  ('혐의', 8),
#  ('보호', 8),
#  ('제휴', 8),
#  ('결합', 8),
#  ('쿠팡', 8),
#  ('크게', 8),
#  ('축산', 8),
#  ('농식품부', 8),
#  ('요약', 8),
#  ('준비', 8),
#  ('육성', 8),
#  ('실무', 8),
#  ('떨어지다', 8),
#  ('도민', 8),
#  ('좋다', 8),
#  ('단위', 8),
#  ('가능성', 8),
#  ('TIPA', 8),
#  ('케이', 8),
#  ('금액', 8),
#  ('색조', 8),
#  ('올리브영', 8),
#  ('타코', 8),
#  ('SOPR', 8),
#  ('제주항공', 8),
#  ('진흥', 7),
#  ('넘다', 7),
#  ('규모', 7),
#  ('개월', 7),
#  ('웨어', 7),
#  ('러블', 7),
#  ('일상', 7),
#  ('처음', 7),
#  ('2월', 7),
#  ('여러', 7),
#  ('경쟁', 7),
#  ('인정받다', 7),
#  ('2019년', 7),
#  ('ICT', 7),
#  ('이야기', 7),
#  ('회원', 7),
#  ('더욱', 7),
#  ('전반', 7),
#  ('트랜스', 7),
#  ('메이', 7),
#  ('가상화', 7),
#  ('현대', 7),
#  ('코드', 7),
#  ('주목', 7),
#  ('접근', 7),
#  ('달러', 7),
#  ('가공', 7),
#  ('도르다', 7),
#  ('자다', 7),
#  ('1년', 7),
#  ('연간', 7),
#  ('매년', 7),
#  ('수치', 7),
#  ('IT', 7),
#  ('생각', 7),
#  ('가지', 7),
#  ('최적화', 7),
#  ('에스원', 7),
#  ('주다', 7),
#  ('관제', 7),
#  ('간의', 7),
#  ('사고', 7),
#  ('잠재', 7),
#  ('융합', 7),
#  ('뷰티', 7),
#  ('움직임', 7),
#  ('제시', 7),
#  ('인기', 7),
#  ('누구', 7),
#  ('경북', 7),
#  ('스마트폰', 7),
#  ('면서', 7),
#  ('하우스', 7),
#  ('측은', 7),
#  ('구조', 7),
#  ('인수', 7),
#  ('미디어', 7),
#  ('금지', 7),
#  ('2018년', 7),
#  ('제안', 7),
#  ('협회', 7),
#  ('체인', 7),
#  ('1월', 7),
#  ('나오다', 7),
#  ('위기', 7),
#  ('트랩', 7),
#  ('써머', 7),
#  ('사가', 7),
#  ('카카오', 7),
#  ('특별', 7),
#  ('남성', 7),
#  ('세우다', 7),
#  ('어느', 7),
#  ('상위', 7),
#  ('커머스', 7),
#  ('연령', 7),
#  ('텔레콤', 7),
#  ('놀다', 7),
#  ('단어', 7),
#  ('프로', 7),
#  ('신세계', 7),
#  ('교환', 7),
#  ('지선', 7),
#  ('매도', 7),
#  ('크립', 7),
#  ('베이스', 7),
#  ('동아리', 7),
#  ('경진', 7),
#  ('우수', 6),
#  ('2년', 6),
#  ('키우다', 6),
#  ('의약', 6),
#  ('뱅크', 6),
#  ('실종자', 6),
#  ('어렵다', 6),
#  ('발견', 6),
#  ('설계', 6),
#  ('영상', 6),
#  ('착용', 6),
#  ('기간', 6),
#  ('스케', 6),
#  ('창업', 6),
#  ('한계', 6),
#  ('오픈', 6),
#  ('상공', 6),
#  ('무료', 6),
#  ('회복', 6),
#  ('등장', 6),
#  ('각종', 6),
#  ('코리아', 6),
#  ('비롯', 6),
#  ('옵스', 6),
#  ('브릭', 6),
#  ('화하다', 6),
#  ('접근성', 6),
#  ('품질', 6),
#  ('사람', 6),
#  ('13', 6),
#  ('신뢰', 6),
#  ('도출', 6),
#  ('프로세스', 6),
#  ('얻다', 6),
#  ('부문', 6),
#  ('아키텍처', 6),
#  ('높아지다', 6),
#  ('향후', 6),
#  ('부산', 6),
#  ('관광', 6),
#  ('주도하다', 6),
#  ('라우', 6),
#  ('성숙', 6),
#  ('24일', 6),
#  ('고위', 6),
#  ('나타내다', 6),
#  ('걸치다', 6),
#  ('중앙', 6),
#  ('중요성', 6),
#  ('이어지다', 6),
#  ('기여', 6),
#  ('총괄', 6),
#  ('반면', 6),
#  ('손해', 6),
#  ('26일', 6),
#  ('두다', 6),
#  ('공개', 6),
#  ('입지', 6),
#  ('나이스', 6),
#  ('싶다', 6),
#  ('각각', 6),
#  ('밸리', 6),
#  ('농촌', 6),
#  ('해오다', 6),
#  ('등록', 6),
#  ('판매', 6),
#  ('유입', 6),
#  ('특성', 6),
#  ('최적', 6),
#  ('저장', 6),
#  ('설립', 6),
#  ('공공기관', 6),
#  ('접종', 6),
#  ('선제', 6),
#  ('17일', 6),
#  ('차별', 6),
#  ('공간', 6),
#  ('제조', 6),
#  ('내다', 6),
#  ('실시간', 6),
#  ('범위', 6),
#  ('해주다', 6),
#  ('노선', 6),
#  ('원장', 6),
#  ('오미크론', 6),
#  ('비율', 6),
#  ('10', 6),
#  ('집계', 6),
#  ('모바일', 6),
#  ('apos', 6),
#  ('요일', 6),
#  ('계기', 6),
#  ('이제', 6),
#  ('추천', 6),
#  ('지금', 6),
#  ('이동', 6),
#  ('클래스', 6),
#  ('50', 6),
#  ('하지만', 6),
#  ('속도', 6),
#  ('핏빗', 6),
#  ('보고', 6),
#  ('전공자', 6),
#  ('금융투자', 6),
#  ('씨젠', 6),
#  ('증권', 6),
#  ('블록', 6),
#  ('급락', 6),
#  ('들이다', 5),
#  ('문제', 5),
#  ('겪다', 5),
#  ('기기', 5),
#  ('가족', 5),
#  ('종합', 5),
#  ('검토', 5),
#  ('운용', 5),
#  ('7월', 5),
#  ('인근', 5),
#  ('행정안전부', 5),
#  ('협의', 5),
#  ('고려', 5),
#  ('추적', 5),
#  ('홀터', 5),
#  ('다만', 5),
#  ('40', 5),
#  ('환자', 5),
#  ('현장', 5),
#  ('없이', 5),
#  ('규제', 5),
#  ('이내', 5),
#  ('꼽히다', 5),
#  ('3년', 5),
#  ('과거', 5),
#  ('갖추다', 5),
#  ('덧붙이다', 5),
#  ('알다', 5),
#  ('배달', 5),
#  ('나누다', 5),
#  ('인간', 5),
#  ('폭발', 5),
#  ('구현', 5),
#  ('필수', 5),
#  ('하나', 5),
#  ('버스', 5),
#  ('테스트', 5),
#  ('시각', 5),
#  ('거나', 5),
#  ('활발하다', 5),
#  ('흐름', 5),
#  ('유연하다', 5),
#  ('성장하다', 5),
#  ('아태', 5),
#  ('부사', 5),
#  ('파이낸셜뉴스', 5),
#  ('12월', 5),
#  ('허브', 5),
#  ('포털', 5),
#  ('특화된', 5),
#  ('기획', 5),
#  ('자의', 5),
#  ('수익', 5),
#  ('라이프', 5),
#  ('그리고', 5),
#  ('밉다', 5),
#  ('거치다', 5),
#  ('시기', 5),
#  ('유형', 5),
#  ('네트워크', 5),
#  ('대규모', 5),
#  ('프로젝트', 5),
#  ('초점', 5),
#  ('광고', 5),
#  ('담기다', 5),
#  ('신청', 5),
#  ('자사', 5),
#  ('요구', 5),
#  ('해당', 5),
#  ('브랜드', 5),
#  ('니즈', 5),
#  ('전원', 5),
#  ('촬영', 5),
#  ('작년', 5),
#  ('기사', 5),
#  ('과학기술', 5),
#  ('대별', 5),
#  ('체결', 5),
#  ('선택', 5),
#  ('델타', 5),
#  ('보완', 5),
#  ('레이스', 5),
#  ('가지다', 5),
#  ('남다', 5),
#  ('행동', 5),
#  ('시너지', 5),
#  ('재판매', 5),
#  ('조성', 5),
#  ('도약', 5),
#  ('황규', 5),
#  ('사항', 5),
#  ('지수', 5),
#  ('개통', 5),
#  ('오후', 5),
#  ('개최', 5),
#  ('2007년', 5),
#  ('낮다', 5),
#  ('CDC', 5),
#  ('사망자', 5),
#  ('의지', 5),
#  ('주민', 5),
#  ('월요일', 5),
#  ('대학', 5),
#  ('상장', 5),
#  ('흩어지다', 5),
#  ('조회', 5),
#  ('30', 5),
#  ('서초', 5),
#  ('서초구', 5),
#  ('업데이트', 5),
#  ('토대', 5),
#  ('KISTI', 5),
#  ('커지다', 5),
#  ('탈잉', 5),
#  ('할인', 5),
#  ('다발', 5),
#  ('몰다', 5),
#  ('노원구', 5),
#  ('살펴보다', 5),
#  ('컨테이너', 5),
#  ('접속', 5),
#  ('숙소', 5),
#  ('즐기다', 5),
#  ('호텔', 5),
#  ('출처', 5),
#  ('명세서', 5),
#  ('혜택', 5),
#  ('떼다', 5),
#  ('비슷하다', 5),
#  ('직장인', 5),
#  ('차이', 5),
#  ('주식', 5),
#  ('장이', 5),
#  ('물류', 5),
#  ('SSTC', 5),
#  ('경품', 5),
#  ('매수', 5),
#  ('GBTC', 5),
#  ('탑승', 5),
#  ('리프', 5),
#  ('레시', 5),
#  ('TP', 4),
#  ('전문성', 4),
#  ('틀다', 4),
#  ('1일', 4),
#  ('연구원', 4),
#  ('제도', 4),
#  ('중구', 4),
#  ('60', 4),
#  ('독자', 4),
#  ('개정', 4),
#  ('수가', 4),
#  ('필요', 4),
#  ('가량', 4),
#  ('편리하다', 4),
#  ('메모', 4),
#  ('패치', 4),
#  ('부정맥', 4),
#  ('조기', 4),
#  ('샌드박스', 4),
#  ('열리다', 4),
#  ('주간', 4),
#  ('측정', 4),
#  ('주제', 4),
#  ('상승', 4),
#  ('양질', 4),
#  ('소개', 4),
#  ('인구', 4),
#  ('방법', 4),
#  ('인터뷰', 4),
#  ('ESG', 4),
#  ('가입', 4),
#  ('이슈', 4),
#  ('부상', 4),
#  ('메타', 4),
#  ('도구', 4),
#  ('능력', 4),
#  ('여기', 4),
#  ('알고리즘', 4),
#  ('역시', 4),
#  ('배포', 4),
#  ('논의', 4),
#  ('위치', 4),
#  ('형식', 4),
#  ('마켓', 4),
#  ('베다', 4),
#  ('청년', 4),
#  ('인턴', 4),
#  ('시설', 4),
#  ('매칭', 4),
#  ('월간', 4),
#  ('레저', 4),
#  ('시민', 4),
#  ('신용카드', 4),
#  ('해내다', 4),
#  ('보고서', 4),
#  ('매우', 4),
#  ('대부분', 4),
#  ('사이클', 4),
#  ('동의', 4),
#  ('투자가', 4),
#  ('장소', 4),
#  ('95%', 4),
#  ('실현', 4),
#  ('의사', 4),
#  ('15', 4),
#  ('주택', 4),
#  ('카페', 4),
#  ('전통', 4),
#  ('방역', 4),
#  ('증거', 4),
#  ('예방', 4),
#  ('System', 4),
#  ('기르다', 4),
#  ('계약', 4),
#  ('홍보', 4),
#  ('요청', 4),
#  ('형태', 4),
#  ('출범', 4),
#  ('전자', 4),
#  ('피부', 4),
#  ('동시', 4),
#  ('제작', 4),
#  ('마을', 4),
#  ('개편', 4),
#  ('품목', 4),
#  ('실태', 4),
#  ('편의', 4),
#  ('강점', 4),
#  ('손잡다', 4),
#  ('획득', 4),
#  ('스토리', 4),
#  ('스트리밍', 4),
#  ('협약', 4),
#  ('정밀', 4),
#  ('바이오', 4),
#  ('기적', 4),
#  ('100만', 4),
#  ('업그레이드', 4),
#  ('개념', 4),
#  ('레이', 4),
#  ('팩토리', 4),
#  ('투입', 4),
#  ('장관', 4),
#  ('산업혁명', 4),
#  ('제정', 4),
#  ('책임', 4),
#  ('점검', 4),
#  ('백신', 4),
#  ('실내', 4),
#  ('세다', 4),
#  ('행사', 4),
#  ('지출', 4),
#  ('앞서', 4),
#  ('미리', 4),
#  ('제주', 4),
#  ('충남', 4),
#  ('입원', 4),
#  ('일치', 4),
#  ('현지', 4),
#  ('감염', 4),
#  ('19일', 4),
#  ('아동', 4),
#  ('상대', 4),
#  ('성인', 4),
#  ('비다', 4),
#  ('양성', 4),
#  ('재계', 4),
#  ('단체', 4),
#  ('경상북도', 4),
#  ('국무총리', 4),
#  ('11회', 4),
#  ('53회', 4),
#  ('외부', 4),
#  ('처방', 4),
#  ('성향', 4),
#  ('구독', 4),
#  ('되어다', 4),
#  ('모집', 4),
#  ('2시', 4),
#  ('수량', 4),
#  ('인재', 4),
#  ('순위', 4),
#  ('취업', 4),
#  ('위원', 4),
#  ('하루', 4),
#  ('경기', 4),
#  ('넷플릭스', 4),
#  ('회의', 4),
#  ('정리', 4),
#  ('시간대', 4),
#  ('차량', 4),
#  ('부품', 4),
#  ('완성', 4),
#  ('구역', 4),
#  ('수강', 4),
#  ('로스', 4),
#  ('도시', 4),
#  ('노원', 4),
#  ('서버', 4),
#  ('단축', 4),
#  ('대출', 4),
#  ('휴식', 4),
#  ('포스트', 4),
#  ('and', 4),
#  ('일부', 4),
#  ('에너지', 4),
#  ('비타민', 4),
#  ('쏘다', 4),
#  ('황건우', 4),
#  ('상상', 4),
#  ('국제', 4),
#  ('힘들다', 4),
#  ('감안', 4),
#  ('GEP', 4),
#  ('지디넷', 4),
#  ...]

# %%
# 내림차순 정렬된 단어 중 상위 50개를 살펴보면 다음과 같습니다.

# ('데이터', 538),
for word, count in sorted_word_dic[:50]:
    print("{0}({1})".format(word, count), end=" ")
# Out:
# 데이터(538) 분석(252) 서비스(154) 빅데이터(115) 활용(102) 기업(96) 기술(93) 개발(89) 사업(86) 고객(86) 제공(85) 통해(83) 늘다(71) 디지털(70) 시스템(69) 기반(68) 지역(62) AI(61) 금융(61) 지난해(60) 플랫폼(59) 시장(59) 관리(56) 혁신(51) 다양하다(51) 지원(50) 밝히다(50) 대표(50) 산업(50) 솔루션(49) 카드(49) 위해(48) 구축(46) 올해(46) 계획(45) 가다(45) 마이(45) 서울(44) 정보(44) 크다(44) 추진(43) 분야(43) 코로나(43) 환경(43) 오다(41) 대한(41) 이번(40) 공공(40) 상품(40) 높다(39)

# %% [markdown]
# <br>
#
# ### 2-4) 단어 등장 빈도 시각화

# %%
# matplot 에서 한글을 표시하기 위한 설정입니다.
# 맑은고딕 대신 나눔고딕 폰트를 사용하려면 [나눔고딕파일] 폴더의 파일들을 복사하여, C drive -> Windows -> Fonts 폴더 안에 붙여넣기합니다.

import nltk
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 위치를 넣어주세요 (위에서 나눔고딕 파일을 해당 경로에 복사붙여넣기 했을 경우 그대로 실행하셔도 무방합니다.)
font_name = matplotlib.font_manager.FontProperties(fname="NanumSquareB.ttf").get_name() # NanumGothic.otf
matplotlib.rc('font', family=font_name)
font_manager.findfont(prop="NanumSquareB.ttf")
# Out:
# '/shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
# nltk 라이브러리는 단어의 등장 빈도를 더욱 쉽게 셀 수 있는 .Text() 함수를 제공합니다.
font_name = matplotlib.font_manager.FontProperties(fname="/shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf").get_name() # NanumGothic.otf
matplotlib.rc('font', family=font_name)
print(font_manager.findfont(prop="NanumSquareB.ttf"))
word_counted = nltk.Text(word_cleaned) 
plt.figure(figsize=(15, 7)) # plot 영역(그래프 영역)의 크기를 지정합니다.
word_counted.plot(50) # "plot" the graph, 상위 50개 단어를 보여줍니다.
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# <br>
#
# ### 2-5) 단어 등장 빈도 시각화 (막대그래프)

# %%
# 막대그래프로의 시각화는 NLTK 의 함수만으로 진행하기 어려우므로,
# NLTK의 FreqDist 함수를 적용한 후 Pandas의 Dataframe에 데이터를 담은 다음 시각화를 진행합니다.
import pandas as pd
word_frequency = nltk.FreqDist(word_cleaned) # Frequency Distribution
pd.DataFrame(word_frequency.items()).head()
# Out:
#      0   1
# 0   인천  15
# 1  뉴시스  13
# 2   루비   2
# 3   기자  20
# 4  테크노   3

# %%
# 단어 빈도가 담긴 Dict 로부터 값을 가져와 DataFrame 을 만듭니다.
df = pd.DataFrame(list(word_frequency.values()), word_frequency.keys()) 

# 빈도 내림차순으로 정렬합니다.
result = df.sort_values([0], ascending=False)

# 전체 데이터(단어 수)는 너무 많기 때문에 출현 횟수 상위 50개만 가져와 시각화합니다.
result = result[:50]
result
# Out:
#         0
# 데이터   538
# 분석    252
# 서비스   154
# 빅데이터  115
# 활용    102
# 기업     96
# 기술     93
# 개발     89
# 고객     86
# 사업     86
# 제공     85
# 통해     83
# 늘다     71
# 디지털    70
# 시스템    69
# 기반     68
# 지역     62
# AI     61
# 금융     61
# 지난해    60
# 시장     59
# 플랫폼    59
# 관리     56
# 다양하다   51
# 혁신     51
# 밝히다    50
# 산업     50
# 대표     50
# 지원     50
# 카드     49
# 솔루션    49
# 위해     48
# 올해     46
# 구축     46
# 마이     45
# 가다     45
# 계획     45
# 크다     44
# 정보     44
# 서울     44
# 추진     43
# 분야     43
# 환경     43
# 코로나    43
# 오다     41
# 대한     41
# 이번     40
# 공공     40
# 상품     40
# 높다     39

# %%
# 데이터프레임에 담긴 단어 및 빈도 수를 막대그래프로 표현하기 위한 코드입니다.

result.plot(kind='bar', legend=False, figsize=(15,5)) # 'bar' graph
result.plot()
# 그림 사이즈를 변경하고 싶을 경우 figsize=(가로, 세로) 를 변경합니다.
# 기타 그래프 관련 옵션은 https://goo.gl/YNejGt 에서 확인하고 적용하실 수 있습니다.

plt.show()

# %% [markdown]
# <br>
# <br>
#
# ## 3. 워드클라우드 만들기

# %% [markdown]
# - 워드클라우드를 만들기에 앞서 WordCloud library 를 설치해주어야 합니다.
#
# - [ 시작메뉴 -  모든 프로그램 - Anaconda 3 - **Anaconda Prompt** ] 에서 아래 명령어를 입력합니다. (우클릭 후 **"관리자권한으로 실행"**)
# <br><br><span style="color:red;">**conda install -c https://conda.anaconda.org/conda-forge wordcloud==1.5.0</span>**
# <br><br> (MacOS : **pip install wordcloud==1.5.0**)

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.6/458.6 KB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud) (1.23.4)
# Requirement already satisfied: pillow in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.9/py/lib/python3.9/site-packages (from wordcloud) (3.6.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# WordCloud 패키지를 import 합니다.
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image # 만약 "No module named 'PIL'" 에러가 발생하면 [ pip install Pillow==5.4.1 ] 로 라이브러리를 설치해줍니다.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <br>
#
# #### 3-1) WordCloud - 하얀 바탕

# %%
# WordCloud 객체를 생성합니다.
# 아래 보이는 코드의 font_path 에 해당하는 부분이 워드클라우드의 폰트에 적용됩니다. (대체로 고딕 계열 폰트가 이쁘게 나옵니다)
# 만약 다른 폰트를 적용하려면, C > Windows > Fonts 폴더에 원하시는 폰트 파일(.ttf)을 넣은 후 아래 코드에서 font 이름을 수정해줍니다.

word_cloud = WordCloud(font_path="/work/NanumSquareB.ttf",
                       # font_path="/shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf", 
                       # font_path="C:/Windows/Fonts/NanumSquareB.ttf" <- 나눔스퀘어 폰트가 설치되어 있을 경우
                       # font_path="/System/Library/Fonts/Supplemental/AppleGothic.ttf <- MacOS의 경우
                       
                       width=2000, height=1000, # 이 부분을 수정하시면 실제 워드클라우드의 크기가 바뀝니다 (해상도가 바뀝니다)
                       prefer_horizontal= 1.0, # 이 부분의 주석을 해제하시면 단어들이 가로로만 그려지게 됩니다. (0~1)
                       background_color='white')

# %%
word_cloud.generate_from_frequencies(word_dic) # Generate wordcloud from word "frequency" data.

# word_cloud.generate(text) : dict 가 아닌 줄글 텍스트 원문으로부터 워드클라우드를 만들 수도 있습니다.

# %%
# 생성한 WordCloud 객체로부터 워드클라우드를 보여주는 코드입니다.

plt.figure(figsize=(15,15)) # 이 부분을 수정하시면 화면에서 보여지는 워드클라우드의 크기가 바뀝니다 
plt.imshow(word_cloud) # image show
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-2) WordCloud - 하얀 바탕, 최대 단어 갯수 50

# %%
# max_words 라는 옵션을 통해 워드클라우드에 담길 단어의 최대 갯수를 제한할 수 있습니다.
# 기본적으로 옵션을 지정하지 않으면 200 으로 default 값이 지정되어 있습니다.

word_cloud = WordCloud(font_path="/work/NanumSquareB.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       max_words=100, # max words
                       prefer_horizontal= 1.0,
                       width=2000, height=1000, 
                       background_color='white').generate_from_frequencies(word_dic)


# 생성한 WordCloud 객체로부터 워드클라우드를 보여주는 코드입니다.

plt.figure(figsize=(15,15)) # 이 부분을 수정하시면 화면에서 보여지는 워드클라우드의 크기가 바뀝니다 
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-3) WordCloud - 검정 바탕, 최대 폰트 사이즈 100

# %%
# max_font_size 라는 옵션을 통해 최대 글자 크기를 제한할 수 있습니다.

# 아래 옵션 중 어느 것을 지워줘야 바탕이 검정(default)이 될까요?
word_cloud = WordCloud(font_path="/work/NanumSquareB.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, 
                       max_font_size=100).generate_from_frequencies(word_dic) # Max font-size

plt.figure(figsize=(15,15))
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-4) WordCloud - masking 적용 (특정 그림 테두리 내에 워드클라우드 그리기)

# %%
python_coloring = np.array(Image.open("python_mask.jpg"))

word_cloud = WordCloud(font_path="/work/NanumSquareB.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000, 
                       mask=python_coloring, # "마스크를 씌운다"라고 표현합니다. (masking)
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
#
# #### 3-5) WordCloud - masking 적용 (특정 그림 테두리 내에 워드클라우드 그리기 & 그림 색상으로 전체 색상 통일)

# %%
from wordcloud import ImageColorGenerator # Image 로부터 Color 를 생성(Generate)해내는 객체입니다.

python_coloring = np.array(Image.open("python_mask.jpg"))
image_colors = ImageColorGenerator(python_coloring)

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", # font_path="C:/Windows/Fonts/NanumSquareB.ttf"
                       width=2000, height=1000,  
                       mask=python_coloring, 
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15))
plt.imshow(word_cloud.recolor(color_func=image_colors), interpolation='bilinear') # 다시(re) 색칠하기
# plt.imshow(word_cloud.?(colormap='Blues'), interpolation='bilinear') # Matplotlib colormap 활용 (http://j.mp/32UXOQ6)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <br>
# <br>
#
# #### 3-6) 워드클라우드를 이미지 파일로 저장하기

# %%
# 아래 코드를 실행하시면 jupyter notebook 과 동일한 폴더에 워드클라우드가 이미지 파일로 저장된 것을 확인하실 수 있습니다.

word_cloud.to_file("word_cloud_completed.png") # Save "to file"

# %% [markdown]
# <br>
#
# #### 3-7) WordCloud 요약 (완성본)

# %%
# 아래 옵션들을 원하시는대로 지정하셔서 가장 마음에 드는 워드클라우드를 활용하시면 됩니다.

word_cloud = WordCloud(font_path="/work/NanumSquareB.ttf", # 한글 폰트 변경
                       width=2000, height=1000, # 실제 워드클라우드 크기 변경 (해상도 변경)
                       max_words=100, # 최대로 보여질 단어 수 제한
                       background_color='white', # 바탕색 지정 (주석처리할 경우 검정으로 변경됨)
#                        max_font_size=100, # 최대 단어 크기 제한
                      ).generate_from_frequencies(word_dic)

plt.figure(figsize=(15,15)) # Jupyter notebook 상에서 보여지는 워드클라우드 크기 지정 
plt.imshow(word_cloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# word_cloud.to_file("word_cloud_7 (white, squared, max100).png")

# %% [markdown]
# <br>
#
# #### Appendix) Try other masks!

# %%
from wordcloud import ImageColorGenerator # Image 로부터 Color 를 생성(Generate)해내는 객체입니다.

korea_coloring = np.array(Image.open("other masks/korea_mask.jpg"))
# image_colors = ImageColorGenerator(korea_coloring)

word_cloud = WordCloud(font_path="C:/Windows/Fonts/malgun.ttf", 
                       width=1600, height=1000, 
                       mask=korea_coloring, 
                       background_color='white').generate_from_frequencies(word_dic)

plt.figure(figsize=(10,10))
plt.imshow(word_cloud.recolor(colormap="Blues"), interpolation='bilinear') # Matplotlib colormap 활용 (http://j.mp/32UXOQ6)
# plt.imshow(word_cloud.recolor(color_func=image_colors), interpolation='bilinear') # 다시(re) 색칠하기
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# word_cloud.to_file("other_masks_applied.png")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b844bbc7-67c4-4320-a052-bd9703f8a211' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
