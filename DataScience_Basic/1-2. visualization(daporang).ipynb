# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 4.1 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
#Settings
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('helloworld.xlsx')
df.rename(columns = {'Unnamed: 0' : 'date'}, inplace = True)
df = pd.pivot_table(df, index='date', aggfunc=np.sum)

# %%
df = df.T[df.index[:-7] ]
df = df.T

# %%
#for x in range(len(df.index)):
#    df.loc[df.index[x],:]
df_columns = list(df.columns)
i = -2
dic = { x : df.loc[ df.index[i], x]  for x in df_columns}
sorted(dic.items(), key = lambda x : x[1], reverse=True)
# Out:
# [('[문학] 고전시가 문제 모음', 246),
#  ('[수학] 수학을 이용한 암호(RSA&동형암호)', 233),
#  ('[물리 & 화학] 신소재', 224),
#  ('[물리] 중력', 209),
#  ('[항공우주과학] 항공기 운항의 물리학적 원리', 142),
#  ('[컴퓨터과학] DNA컴퓨팅', 126),
#  ('[지구과학] 퇴적암', 62),
#  ('[컴퓨터과학] 컴퓨터 비전(Computer Vision)', 49),
#  ('[물리] 빛과 빛의 활용', 41),
#  ('[화학] 물질의 반응과 평형', 35),
#  ('[문학] 종로 5가 _ 신동엽', 26),
#  ('[지리] 한반도 기후의 발생', 25),
#  ('[음악] 잔나비 - 주저하는 연인들을 위해', 17),
#  ('[항공우주과학] 항공기의 기초', 17),
#  ('[스포츠] 동계스포츠', 14),
#  ('[음악] 퀸 - 보헤미안 랩소디 악보 (Bohemian Rhapsody)', 13),
#  ('[수학] 행렬의 기초', 9),
#  ('[경제학] 회계의 구성요소', 7),
#  ('[물리] 양자역학', 5),
#  ('마크 피터슨 [평화로운 한국 역사] _ Part.1', 3),
#  ('[이미지 출처 모음]', 2),
#  ('[Music] Bohemian Rhapsody Sheet Music', 1),
#  ('마크 피터슨 [평화로운 한국 역사] _ Part.2', 1),
#  ('팻두 [죽은 친구와의 전화]', 1),
#  ("(G)I-DLE_'Silhdago Malhae'_(Put it straight_Nightmare.Ver.)", 0),
#  ('[Music] For Lovers Who Hesitate', 0),
#  ('[경제학] 회계의 기초', 0),
#  ('[물리] 탄성력', 0),
#  ('[법] 헌법', 0),
#  ('[수학] 행렬', 0),
#  ('[컴퓨터과학] SW테스팅', 0),
#  ('신카이 마코토 [너의 이름은]', 0)]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3187d24c-8239-48fe-baa3-3e50b91ad20b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
